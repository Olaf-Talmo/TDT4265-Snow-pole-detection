# %% [markdown]
# # Changing anchor bounding boxes
# This implementation of yolo only has one category, snow poles. Since all snow poles are shaped the same, they are long and thin, we attempt to change the anchor boxes accordingly. We want all anchor boxes to be long and thin.

# %% [markdown]
# ### Installing required packages

# %%
#!git clone https://github.com/sunsmarterjie/yolov12
# %cd yolov12
# %pip install roboflow supervision flash-attn --upgrade -q
# %pip install -r requirements.txt
# %pip install -e .
# %pip install --upgrade flash-attn

# Not in tutorial but necesarry:
# %pip install huggingface_hub ultralytics
# Out:
# /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Requirement 'flash_attn-2.7.3+cu11torch2.2cxx11abiFALSE-cp311-cp311-linux_x86_64.whl' looks like a filename, but the file does not exist
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# ERROR: flash_attn-2.7.3+cu11torch2.2cxx11abiFALSE-cp311-cp311-linux_x86_64.whl is not a supported wheel on this platform.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# Obtaining file:///home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.63) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.63) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.63) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.63) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.63) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.63) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/lib/python3/dist-packages (from ultralytics==8.3.63) (1.3.5)
# Requirement already satisfied: seaborn>=0.11.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics==8.3.63) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.3.63) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.63) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.63) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.63) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.63) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.63) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.63) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.63) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.3.63) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.3.63) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->ultralytics==8.3.63) (2020.6.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (3.12.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (4.9.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (1.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (3.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.63) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.3.63) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics==8.3.63) (12.2.140)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.63) (1.16.0)
# Building wheels for collected packages: ultralytics
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.63-0.editable-py3-none-any.whl size=19740 sha256=1d8b956aa432618a34d08884e78091b9d88893f86bb2a40a3afecdfe649e21e6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4lx12cxs/wheels/66/e9/2d/a060eee929636f0211d44608914758af98bba375b5925daca3
# Successfully built ultralytics
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.63
#     Uninstalling ultralytics-8.3.63:
#       Successfully uninstalled ultralytics-8.3.63
# Successfully installed ultralytics-8.3.63
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# Requirement already satisfied: flash-attn in /home/omtalmo/.local/lib/python3.10/site-packages (2.7.4.post1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn) (2.4.1)
# Requirement already satisfied: einops in /home/omtalmo/.local/lib/python3.10/site-packages (from flash-attn) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.12.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (4.9.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch->flash-attn) (1.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch->flash-attn) (3.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from torch->flash-attn) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash-attn) (12.2.140)
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# Requirement already satisfied: huggingface_hub in /home/omtalmo/.local/lib/python3.10/site-packages (0.30.2)
# Requirement already satisfied: ultralytics in /home/omtalmo/.local/lib/python3.10/site-packages (8.3.63)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.9.2)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3/dist-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /home/omtalmo/.local/lib/python3.10/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.9.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/lib/python3/dist-packages (from ultralytics) (1.3.5)
# Requirement already satisfied: seaborn>=0.11.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->huggingface_hub) (2020.6.20)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.8.0->ultralytics) (1.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.2.140)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# WARNING: Ignoring invalid distribution -ip (/usr/local/lib/python3.10/dist-packages)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Loading dataset
# The data is structured like this: I have one folder called "rgb". Inside the folder is a data.yaml file, a folder called "images" and a folder called "labels". The folder "images" contains the subfolders "test", "train" and "valid", which all contain png files. The folder "labels" contain the subfolders "train" and "valid", which both contain txt files.

# %%
dataset_path = "/home/omtalmo/Olaf_TTK4265/Poles/rgb"

# %%
from ultralytics import YOLO

# Initialize model with previously trained weights
model_path = "/home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12/runs/detect/train2/weights/best.pt"
model = YOLO(model_path)

# Train the model with your custom dataset
results = model.train(
    data=f'{dataset_path}/data.yaml',
    epochs=250,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24096MiB)
# engine/trainer: task=detect, mode=train, model=/home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12/runs/detect/train2/weights/best.pt, data=/home/omtalmo/Olaf_TTK4265/Poles/rgb/data.yaml, epochs=250, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.1, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1      9344  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2, 1, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1     37120  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2, 1, 4]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  2    677120  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 4]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  2   2664960  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     95104  ultralytics.nn.modules.block.A2C2f           [512, 128, 1, False, -1]
#  15                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1    296704  ultralytics.nn.modules.block.A2C2f           [384, 256, 1, False, -1]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  21        [14, 17, 20]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLOv12s summary: 497 layers, 9,096,851 parameters, 9,096,835 gradients, 19.6 GFLOPs
#
# Transferred 739/739 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train4', view at http://localhost:6006/
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /home/omtalmo/Olaf_TTK4265/Poles/rgb/labels/train.cache... 322 images, 0 backgrounds, 0 corrupt: 100%|██████████| 322/322 [00:00<?, ?it/s]
# val: Scanning /home/omtalmo/Olaf_TTK4265/Poles/rgb/labels/valid.cache... 92 images, 0 backgrounds, 0 corrupt: 100%|██████████| 92/92 [00:00<?, ?it/s]
# Plotting labels to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 121 weight(decay=0.0), 128 weight(decay=0.0005), 127 bias(decay=0.0)
# TensorBoard: WARNING ⚠️ TensorBoard graph visualization failure Tracing failed sanity checks!
# ERROR: Graphs differed across invocations!
# 	Graph diff:
# 		  graph(%self.1 : __torch__.ultralytics.nn.tasks.DetectionModel,
# 		        %x.1 : Tensor):
# 		    %model : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_21 : __torch__.ultralytics.nn.modules.head.Detect = prim::GetAttr[name="21"](%model)
# 		    %model.43 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_20 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="20"](%model.43)
# 		    %model.41 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_19 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="19"](%model.41)
# 		    %model.39 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_18 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="18"](%model.39)
# 		    %model.37 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_17 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="17"](%model.37)
# 		    %model.35 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_16 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="16"](%model.35)
# 		    %model.33 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_15 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="15"](%model.33)
# 		    %model.31 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_14 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="14"](%model.31)
# 		    %model.29 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_13 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="13"](%model.29)
# 		    %model.27 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_12 : __torch__.torch.nn.modules.upsampling.Upsample = prim::GetAttr[name="12"](%model.27)
# 		    %model.25 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_11 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="11"](%model.25)
# 		    %model.23 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_10 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="10"](%model.23)
# 		    %model.21 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_9 : __torch__.torch.nn.modules.upsampling.Upsample = prim::GetAttr[name="9"](%model.21)
# 		    %model.19 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_8 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="8"](%model.19)
# 		    %model.17 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="7"](%model.17)
# 		    %model.15 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_6 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="6"](%model.15)
# 		    %model.13 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="5"](%model.13)
# 		    %model.11 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_4 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="4"](%model.11)
# 		    %model.9 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="3"](%model.9)
# 		    %model.7 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_2.3 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="2"](%model.7)
# 		    %model.5 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_1.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="1"](%model.5)
# 		    %model.3 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_21.1 : __torch__.ultralytics.nn.modules.head.Detect = prim::GetAttr[name="21"](%model.3)
# 		    %cv3.1 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="cv3"](%_21.1)
# 		    %_2.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="2"](%cv3.1)
# 		    %_1.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="1"](%_2.1)
# 		    %_1.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="1"](%_1.1)
# 		    %act.1 : __torch__.torch.nn.modules.activation.SiLU = prim::GetAttr[name="act"](%_1.3)
# 		    %model.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_0.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="0"](%model.1)
# 		    %75 : int = prim::Constant[value=2](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %76 : int = prim::Constant[value=1](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %77 : bool = prim::Constant[value=0](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %78 : int = prim::Constant[value=0](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %79 : bool = prim::Constant[value=1](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.1 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_0.1)
# 		    %bias.255 : Tensor = prim::GetAttr[name="bias"](%conv.1)
# 		    %weight.257 : Tensor = prim::GetAttr[name="weight"](%conv.1)
# 		    %83 : int[] = prim::ListConstruct(%75, %75), scope: __module.model.0/__module.model.0.conv
# 		    %84 : int[] = prim::ListConstruct(%76, %76), scope: __module.model.0/__module.model.0.conv
# 		    %85 : int[] = prim::ListConstruct(%76, %76), scope: __module.model.0/__module.model.0.conv
# 		    %86 : int[] = prim::ListConstruct(%78, %78), scope: __module.model.0/__module.model.0.conv
# 		    %input.1 : Tensor = aten::_convolution(%x.1, %weight.257, %bias.255, %83, %84, %85, %77, %86, %76, %77, %79, %79, %79), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.3 : Tensor = aten::silu_(%input.1), scope: __module.model.0/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %89 : int = prim::Constant[value=2](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %90 : int = prim::Constant[value=1](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %91 : bool = prim::Constant[value=0](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %92 : int = prim::Constant[value=0](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %93 : bool = prim::Constant[value=1](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.3 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_1.5)
# 		    %bias.257 : Tensor = prim::GetAttr[name="bias"](%conv.3)
# 		    %weight.259 : Tensor = prim::GetAttr[name="weight"](%conv.3)
# 		    %97 : int[] = prim::ListConstruct(%89, %89), scope: __module.model.1/__module.model.1.conv
# 		    %98 : int[] = prim::ListConstruct(%90, %90), scope: __module.model.1/__module.model.1.conv
# 		    %99 : int[] = prim::ListConstruct(%90, %90), scope: __module.model.1/__module.model.1.conv
# 		    %100 : int[] = prim::ListConstruct(%92, %92), scope: __module.model.1/__module.model.1.conv
# 		    %input.5 : Tensor = aten::_convolution(%input.3, %weight.259, %bias.257, %97, %98, %99, %91, %100, %89, %91, %93, %93, %93), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.7 : Tensor = aten::silu_(%input.5), scope: __module.model.1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %103 : int = prim::Constant[value=2](), scope: __module.model.2 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %104 : bool = prim::Constant[value=1](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %105 : bool = prim::Constant[value=0](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %106 : int = prim::Constant[value=0](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %107 : int = prim::Constant[value=1](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %cv2.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_2.3)
# 		    %m.1 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_2.3)
# 		    %_0.3 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="0"](%m.1)
# 		    %cv1.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_2.3)
# 		    %conv.5 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.1)
# 		    %bias.259 : Tensor = prim::GetAttr[name="bias"](%conv.5)
# 		    %weight.261 : Tensor = prim::GetAttr[name="weight"](%conv.5)
# 		    %115 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %116 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %117 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %118 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %input.9 : Tensor = aten::_convolution(%input.7, %weight.261, %bias.259, %115, %116, %117, %105, %118, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %120 : Tensor = aten::silu_(%input.9), scope: __module.model.2/__module.model.2.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %121 : Tensor[] = aten::chunk(%120, %103, %107), scope: __module.model.2 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %122 : Tensor, %input.11 : Tensor = prim::ListUnpack(%121), scope: __module.model.2
# 		    %cv2.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.3)
# 		    %cv1.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.3)
# 		    %conv.7 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.3)
# 		    %bias.261 : Tensor = prim::GetAttr[name="bias"](%conv.7)
# 		    %weight.263 : Tensor = prim::GetAttr[name="weight"](%conv.7)
# 		    %129 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %130 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %131 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %132 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %input.13 : Tensor = aten::_convolution(%input.11, %weight.263, %bias.261, %129, %130, %131, %105, %132, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.15 : Tensor = aten::silu_(%input.13), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %conv.9 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.1)
# 		    %bias.263 : Tensor = prim::GetAttr[name="bias"](%conv.9)
# 		    %weight.265 : Tensor = prim::GetAttr[name="weight"](%conv.9)
# 		    %138 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %139 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %140 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %141 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %input.17 : Tensor = aten::_convolution(%input.15, %weight.265, %bias.263, %138, %139, %140, %105, %141, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %143 : Tensor = aten::silu_(%input.17), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %144 : Tensor = aten::add(%input.11, %143, %107), scope: __module.model.2/__module.model.2.m.0 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:348:0
# 		    %145 : Tensor[] = prim::ListConstruct(%122, %input.11, %144), scope: __module.model.2
# 		    %input.19 : Tensor = aten::cat(%145, %107), scope: __module.model.2 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:240:0
# 		    %conv.11 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.3)
# 		    %bias.265 : Tensor = prim::GetAttr[name="bias"](%conv.11)
# 		    %weight.267 : Tensor = prim::GetAttr[name="weight"](%conv.11)
# 		    %150 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %151 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %152 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %153 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %input.21 : Tensor = aten::_convolution(%input.19, %weight.267, %bias.265, %150, %151, %152, %105, %153, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.23 : Tensor = aten::silu_(%input.21), scope: __module.model.2/__module.model.2.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %156 : int = prim::Constant[value=2](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %157 : int = prim::Constant[value=1](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %158 : bool = prim::Constant[value=0](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %159 : int = prim::Constant[value=0](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %160 : int = prim::Constant[value=4](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %161 : bool = prim::Constant[value=1](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.13 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_3)
# 		    %bias.267 : Tensor = prim::GetAttr[name="bias"](%conv.13)
# 		    %weight.269 : Tensor = prim::GetAttr[name="weight"](%conv.13)
# 		    %165 : int[] = prim::ListConstruct(%156, %156), scope: __module.model.3/__module.model.3.conv
# 		    %166 : int[] = prim::ListConstruct(%157, %157), scope: __module.model.3/__module.model.3.conv
# 		    %167 : int[] = prim::ListConstruct(%157, %157), scope: __module.model.3/__module.model.3.conv
# 		    %168 : int[] = prim::ListConstruct(%159, %159), scope: __module.model.3/__module.model.3.conv
# 		    %input.25 : Tensor = aten::_convolution(%input.23, %weight.269, %bias.267, %165, %166, %167, %158, %168, %160, %158, %161, %161, %161), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.27 : Tensor = aten::silu_(%input.25), scope: __module.model.3/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %171 : int = prim::Constant[value=2](), scope: __module.model.4 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %172 : bool = prim::Constant[value=1](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %173 : bool = prim::Constant[value=0](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %174 : int = prim::Constant[value=0](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %175 : int = prim::Constant[value=1](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %cv2.7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_4)
# 		    %m.3 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_4)
# 		    %_0.5 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="0"](%m.3)
# 		    %cv1.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_4)
# 		    %conv.15 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.5)
# 		    %bias.269 : Tensor = prim::GetAttr[name="bias"](%conv.15)
# 		    %weight.271 : Tensor = prim::GetAttr[name="weight"](%conv.15)
# 		    %183 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %184 : int[] = prim::ListConstruct(%174, %174), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %185 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %186 : int[] = prim::ListConstruct(%174, %174), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %input.29 : Tensor = aten::_convolution(%input.27, %weight.271, %bias.269, %183, %184, %185, %173, %186, %175, %173, %172, %172, %172), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %188 : Tensor = aten::silu_(%input.29), scope: __module.model.4/__module.model.4.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %189 : Tensor[] = aten::chunk(%188, %171, %175), scope: __module.model.4 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %190 : Tensor, %input.31 : Tensor = prim::ListUnpack(%189), scope: __module.model.4
# 		    %cv2.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.5)
# 		    %cv1.7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.5)
# 		    %conv.17 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.7)
# 		    %bias.271 : Tensor = prim::GetAttr[name="bias"](%conv.17)
# 		    %weight.273 : Tensor = prim::GetAttr[name="weight"](%conv.17)
# 		    %197 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %198 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %199 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %200 : int[] = prim::ListConstruct(%174, %174), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %input.33 : Tensor = aten::_convolution(%input.31, %weight.273, %bias.271, %197, %198, %199, %173, %200, %175, %173, %172, %172, %172), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.35 : Tensor = aten::silu_(%input.33), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %conv.19 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.5)
# 		    %bias.273 : Tensor = prim::GetAttr[name="bias"](%conv.19)
# 		    %weight.275 : Tensor = prim::GetAttr[name="weight"](%conv.19)
# 		    %206 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %207 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %208 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %209 : int[] = prim::ListConstruct(%174, %174), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %input.37 : Tensor = aten::_convolution(%input.35, %weight.275, %bias.273, %206, %207, %208, %173, %209, %175, %173, %172, %172, %172), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %211 : Tensor = aten::silu_(%input.37), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %212 : Tensor = aten::add(%input.31, %211, %175), scope: __module.model.4/__module.model.4.m.0 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:348:0
# 		    %213 : Tensor[] = prim::ListConstruct(%190, %input.31, %212), scope: __module.model.4
# 		    %input.39 : Tensor = aten::cat(%213, %175), scope: __module.model.4 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:240:0
# 		    %conv.21 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.7)
# 		    %bias.275 : Tensor = prim::GetAttr[name="bias"](%conv.21)
# 		    %weight.277 : Tensor = prim::GetAttr[name="weight"](%conv.21)
# 		    %218 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.cv2/__module.model.4.cv2.conv
# 		    %219 : int[] = prim::ListConstruct(%174, %174), scope: __module.model.4/__module.model.4.cv2/__module.model.4.cv2.conv
# 		    %220 : int[] = prim::ListConstruct(%175, %175), scope: __module.model.4/__module.model.4.cv2/__module.model.4.cv2.conv
# 		    %221 : int[] = prim::ListConstruct(%174, %174), scope: __module.model.4/__module.model.4.cv2/__module.model.4.cv2.conv
# 		    %input.41 : Tensor = aten::_convolution(%input.39, %weight.277, %bias.275, %218, %219, %220, %173, %221, %175, %173, %172, %172, %172), scope: __module.model.4/__module.model.4.cv2/__module.model.4.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.43 : Tensor = aten::silu_(%input.41), scope: __module.model.4/__module.model.4.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %224 : int = prim::Constant[value=2](), scope: __module.model.5/__module.model.5.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %225 : int = prim::Constant[value=1](), scope: __module.model.5/__module.model.5.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %226 : bool = prim::Constant[value=0](), scope: __module.model.5/__module.model.5.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %227 : int = prim::Constant[value=0](), scope: __module.model.5/__module.model.5.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %228 : bool = prim::Constant[value=1](), scope: __module.model.5/__module.model.5.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.23 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_5)
# 		    %bias.277 : Tensor = prim::GetAttr[name="bias"](%conv.23)
# 		    %weight.279 : Tensor = prim::GetAttr[name="weight"](%conv.23)
# 		    %232 : int[] = prim::ListConstruct(%224, %224), scope: __module.model.5/__module.model.5.conv
# 		    %233 : int[] = prim::ListConstruct(%225, %225), scope: __module.model.5/__module.model.5.conv
# 		    %234 : int[] = prim::ListConstruct(%225, %225), scope: __module.model.5/__module.model.5.conv
# 		    %235 : int[] = prim::ListConstruct(%227, %227), scope: __module.model.5/__module.model.5.conv
# 		    %input.45 : Tensor = aten::_convolution(%input.43, %weight.279, %bias.277, %232, %233, %234, %226, %235, %225, %226, %228, %228, %228), scope: __module.model.5/__module.model.5.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.47 : Tensor = aten::silu_(%input.45), scope: __module.model.5/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %238 : int = prim::Constant[value=2](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1219:0
# 		    %239 : int = prim::Constant[value=3](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1219:0
# 		    %240 : int = prim::Constant[value=-1](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1222:0
# 		    %241 : int = prim::Constant[value=128](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.pe/__module.model.6.m.0.0.attn.pe.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %242 : Tensor = prim::Constant[value={4}](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1228:0
# 		    %243 : Tensor = prim::Constant[value={2}](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1228:0
# 		    %244 : int = prim::Constant[value=4](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1234:0
# 		    %245 : int = prim::Constant[value=32](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1234:0
# 		    %246 : int = prim::Constant[value=5](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1239:0
# 		    %247 : NoneType = prim::Constant(), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn
# 		    %248 : int = prim::Constant[value=6](), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1242:0
# 		    %249 : bool = prim::Constant[value=1](), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %250 : bool = prim::Constant[value=0](), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %251 : int = prim::Constant[value=0](), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %252 : int = prim::Constant[value=1](), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %cv2.9 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_6)
# 		    %m.7 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_6)
# 		    %_1.19 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="1"](%m.7)
# 		    %m.5 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_6)
# 		    %_0.13 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="0"](%m.5)
# 		    %cv1.9 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_6)
# 		    %conv.25 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.9)
# 		    %bias.279 : Tensor = prim::GetAttr[name="bias"](%conv.25)
# 		    %weight.281 : Tensor = prim::GetAttr[name="weight"](%conv.25)
# 		    %262 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv
# 		    %263 : int[] = prim::ListConstruct(%251, %251), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv
# 		    %264 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv
# 		    %265 : int[] = prim::ListConstruct(%251, %251), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv
# 		    %input.49 : Tensor = aten::_convolution(%input.47, %weight.281, %bias.279, %262, %263, %264, %250, %265, %252, %250, %249, %249, %249), scope: __module.model.6/__module.model.6.cv1/__module.model.6.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %x.3 : Tensor = aten::silu_(%input.49), scope: __module.model.6/__module.model.6.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %_1.11 : __torch__.ultralytics.nn.modules.block.ABlock = prim::GetAttr[name="1"](%_0.13)
# 		    %_0.9 : __torch__.ultralytics.nn.modules.block.ABlock = prim::GetAttr[name="0"](%_0.13)
# 		    %mlp.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="mlp"](%_0.9)
# 		    %attn.1 : __torch__.ultralytics.nn.modules.block.AAttn = prim::GetAttr[name="attn"](%_0.9)
# 		    %proj.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="proj"](%attn.1)
# 		    %pe.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="pe"](%attn.1)
# 		    %v.41 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="v"](%attn.1)
# 		    %qk.17 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="qk"](%attn.1)
# 		    %276 : int = aten::size(%x.3, %251), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1219:0
# 		    %B.1 : Tensor = prim::NumToTensor(%276), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn
# 		    %278 : int = aten::size(%x.3, %252), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1219:0
# 		    %C.1 : Tensor = prim::NumToTensor(%278), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn
# 		    %280 : int = aten::size(%x.3, %238), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1219:0
# 		    %H.1 : Tensor = prim::NumToTensor(%280), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn
# 		    %282 : int = aten::size(%x.3, %239), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1219:0
# 		    %W.1 : Tensor = prim::NumToTensor(%282), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn
# 		    %284 : Tensor = aten::mul(%H.1, %W.1), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1220:0
# 		    %conv.27 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%qk.17)
# 		    %bias.281 : Tensor = prim::GetAttr[name="bias"](%conv.27)
# 		    %weight.283 : Tensor = prim::GetAttr[name="weight"](%conv.27)
# 		    %288 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.qk/__module.model.6.m.0.0.attn.qk.conv
# 		    %289 : int[] = prim::ListConstruct(%251, %251), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.qk/__module.model.6.m.0.0.attn.qk.conv
# 		    %290 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.qk/__module.model.6.m.0.0.attn.qk.conv
# 		    %291 : int[] = prim::ListConstruct(%251, %251), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.qk/__module.model.6.m.0.0.attn.qk.conv
# 		    %292 : Tensor = aten::_convolution(%x.3, %weight.283, %bias.281, %288, %289, %290, %250, %291, %252, %250, %249, %249, %249), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.qk/__module.model.6.m.0.0.attn.qk.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %293 : Tensor = aten::flatten(%292, %238, %240), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1222:0
# 		    %qk.1 : Tensor = aten::transpose(%293, %252, %238), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1222:0
# 		    %conv.29 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%v.41)
# 		    %bias.283 : Tensor = prim::GetAttr[name="bias"](%conv.29)
# 		    %weight.285 : Tensor = prim::GetAttr[name="weight"](%conv.29)
# 		    %298 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.v/__module.model.6.m.0.0.attn.v.conv
# 		    %299 : int[] = prim::ListConstruct(%251, %251), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.v/__module.model.6.m.0.0.attn.v.conv
# 		    %300 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.v/__module.model.6.m.0.0.attn.v.conv
# 		    %301 : int[] = prim::ListConstruct(%251, %251), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.v/__module.model.6.m.0.0.attn.v.conv
# 		    %input.51 : Tensor = aten::_convolution(%x.3, %weight.285, %bias.283, %298, %299, %300, %250, %301, %252, %250, %249, %249, %249), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.v/__module.model.6.m.0.0.attn.v.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.31 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%pe.1)
# 		    %bias.285 : Tensor = prim::GetAttr[name="bias"](%conv.31)
# 		    %weight.287 : Tensor = prim::GetAttr[name="weight"](%conv.31)
# 		    %306 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.pe/__module.model.6.m.0.0.attn.pe.conv
# 		    %307 : int[] = prim::ListConstruct(%238, %238), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.pe/__module.model.6.m.0.0.attn.pe.conv
# 		    %308 : int[] = prim::ListConstruct(%252, %252), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.pe/__module.model.6.m.0.0.attn.pe.conv
# 		    %309 : int[] = prim::ListConstruct(%251, %251), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.pe/__module.model.6.m.0.0.attn.pe.conv
# 		    %pp.1 : Tensor = aten::_convolution(%input.51, %weight.287, %bias.285, %306, %307, %308, %250, %309, %241, %250, %249, %249, %249), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn/__module.model.6.m.0.0.attn.pe/__module.model.6.m.0.0.attn.pe.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %311 : Tensor = aten::flatten(%input.51, %238, %240), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1225:0
# 		    %v.1 : Tensor = aten::transpose(%311, %252, %238), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1225:0
# 		    %313 : Tensor = aten::mul(%B.1, %242), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1228:0
# 		    %314 : int = aten::Int(%313), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn
# 		    %315 : Tensor = aten::floor_divide(%284, %242), scope: __module.model.6/__module.model.6.m.0/__module.model.6.m.0.0/__module.model.6.m.0.0.attn # /usr/local/lib/python3.10/dist-packages/torch/_tensor.py
134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115401/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116007/134400 anchors with weight 0.00
#     249/250      4.87G     0.8778     0.5608      0.867         16        640:  67%|██████▋   | 14/21 [00:01<00:00, 13.05it/s]
# it3: [AspectLoss] punished 115392/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115660/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 114805/134400 anchors with weight 0.00
#     249/250      4.87G     0.8965     0.5853     0.8637         18        640:  76%|███████▌  | 16/21 [00:01<00:00, 12.85it/s]
# it3: [AspectLoss] punished 115989/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 114820/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115478/134400 anchors with weight 0.00
#     249/250      4.87G     0.9034     0.5779     0.8673         18        640:  95%|█████████▌| 20/21 [00:01<00:00, 12.36it/s]
# it3: [AspectLoss] punished 115587/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116503/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 14314/16800 anchors with weight 0.00
#     249/250      4.98G     0.9194     0.5747     0.8645          3        640: 100%|██████████| 21/21 [00:01<00:00, 12.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:00<00:00, 11.34it/s]
# it3: [AspectLoss] punished 168056/197568 anchors with weight 0.00
# it3: [AspectLoss] punished 169944/197568 anchors with weight 0.00
# it3: [AspectLoss] punished 149321/172872 anchors with weight 0.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 11.94it/s]
#                    all         92        113      0.843      0.593      0.741       0.49
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     250/250      4.91G     0.8104     0.8991     0.8137         17        640:  10%|▉         | 2/21 [00:00<00:01, 12.64it/s]
# it3: [AspectLoss] punished 115645/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116180/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115504/134400 anchors with weight 0.00
#     250/250      4.91G     0.8164     0.6736     0.8575         16        640:  19%|█▉        | 4/21 [00:00<00:01, 11.85it/s]
# it3: [AspectLoss] punished 115955/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115863/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116674/134400 anchors with weight 0.00
#     250/250      4.91G     0.8401      0.628     0.8671         15        640:  38%|███▊      | 8/21 [00:00<00:01, 11.96it/s]
# it3: [AspectLoss] punished 115451/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115820/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116139/134400 anchors with weight 0.00
#     250/250      4.91G     0.8464     0.6098     0.8606         15        640:  48%|████▊     | 10/21 [00:00<00:00, 12.18it/s]
# it3: [AspectLoss] punished 116302/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116116/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115374/134400 anchors with weight 0.00
#     250/250      4.91G     0.8789     0.6163     0.8748         17        640:  67%|██████▋   | 14/21 [00:01<00:00, 12.26it/s]
# it3: [AspectLoss] punished 115696/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115020/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 114842/134400 anchors with weight 0.00
#     250/250      4.91G     0.8699     0.5985     0.8619         19        640:  76%|███████▌  | 16/21 [00:01<00:00, 11.91it/s]
# it3: [AspectLoss] punished 115122/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116647/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 116078/134400 anchors with weight 0.00
#     250/250      5.02G     0.8759     0.6117     0.8661          4        640: 100%|██████████| 21/21 [00:01<00:00, 12.34it/s]
# it3: [AspectLoss] punished 115789/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 115639/134400 anchors with weight 0.00
# it3: [AspectLoss] punished 14343/16800 anchors with weight 0.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 2/3 [00:00<00:00, 12.28it/s]
# it3: [AspectLoss] punished 167902/197568 anchors with weight 0.00
# it3: [AspectLoss] punished 169931/197568 anchors with weight 0.00
# it3: [AspectLoss] punished 149248/172872 anchors with weight 0.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 12.01it/s]
#                    all         92        113      0.843      0.584      0.734      0.488
# 250 epochs completed in 0.205 hours.
# Optimizer stripped from /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train4/weights/last.pt, 18.6MB
# Optimizer stripped from /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train4/weights/best.pt, 18.6MB
#
# Validating /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train4/weights/best.pt...
# Ultralytics 8.3.63 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24096MiB)
# YOLOv12s summary (fused): 376 layers, 9,074,595 parameters, 0 gradients, 19.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00, 10.58it/s]
#                    all         92        113      0.873      0.609      0.756       0.51
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train4
