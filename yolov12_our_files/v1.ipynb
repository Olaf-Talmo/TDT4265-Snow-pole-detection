# %% [markdown]
# # Plain implementation of YOLOv12 trained on our custom dataset (RGB)
# Created following this tutorial https://blog.roboflow.com/train-yolov12-model/

# %% [markdown]
# ### Installing required packages

# %%
#!git clone https://github.com/sunsmarterjie/yolov12
# %cd yolov12
# %pip install roboflow supervision flash-attn --upgrade -q
# %pip install -r requirements.txt
# %pip install -e .
# %pip install --upgrade flash-attn

# Not in tutorial but necesarry:
# %pip install huggingface_hub ultralytics
# Out:
# [Errno 2] No such file or directory: 'yolov12'
# /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# Obtaining file:///home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12
# ERROR: file:///home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12 does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# Requirement already satisfied: flash-attn in /home/omtalmo/.local/lib/python3.10/site-packages (2.7.4.post1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn) (2.4.1)
# Requirement already satisfied: einops in /home/omtalmo/.local/lib/python3.10/site-packages (from flash-attn) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.12.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (4.9.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch->flash-attn) (1.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch->flash-attn) (3.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from torch->flash-attn) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash-attn) (12.2.140)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# Requirement already satisfied: huggingface_hub in /home/omtalmo/.local/lib/python3.10/site-packages (0.30.2)
# Requirement already satisfied: ultralytics in /home/omtalmo/.local/lib/python3.10/site-packages (8.3.63)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.9.2)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3/dist-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /home/omtalmo/.local/lib/python3.10/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.9.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/lib/python3/dist-packages (from ultralytics) (1.3.5)
# Requirement already satisfied: seaborn>=0.11.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->huggingface_hub) (2020.6.20)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.8.0->ultralytics) (1.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.2.140)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Loading dataset
# The data is structured like this: I have one folder called "rgb". Inside the folder is a data.yaml file, a folder called "images" and a folder called "labels". The folder "images" contains the subfolders "test", "train" and "valid", which all contain png files. The folder "labels" contain the subfolders "train" and "valid", which both contain txt files.

# %%
dataset_path = "/home/omtalmo/Olaf_TTK4265/Poles_cropped/rgb"

# %%
from ultralytics import YOLO

# Initialize YOLOv12 model (s = small version)
model = YOLO('yolov12m.yaml')  

# Train the model using RGB data
results = model.train(
    data=f'{dataset_path}/data.yaml',
    epochs=250
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.108 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24069MiB)
# engine/trainer: task=detect, mode=train, model=yolov12m.yaml, data=/home/omtalmo/Olaf_TTK4265/Poles_cropped/rgb/data.yaml, epochs=250, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.1, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     37120  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2, 1, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    147968  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2, 1, 4]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2664960  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2664960  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLOv12m summary: 533 layers, 19,609,875 parameters, 19,609,859 gradients, 60.1 GFLOPs
#
# TensorBoard: Start with 'tensorboard --logdir /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /home/omtalmo/Olaf_TTK4265/Poles_cropped/rgb/labels/train... 322 images, 0 backgrounds, 0 corrupt: 100%|██████████| 322/322 [00:00<00:00, 900.95it/s]
# train: New cache created: /home/omtalmo/Olaf_TTK4265/Poles_cropped/rgb/labels/train.cache
# val: Scanning /home/omtalmo/Olaf_TTK4265/Poles_cropped/rgb/labels/valid... 92 images, 0 backgrounds, 0 corrupt: 100%|██████████| 92/92 [00:00<00:00, 573.23it/s]
# val: New cache created: /home/omtalmo/Olaf_TTK4265/Poles_cropped/rgb/labels/valid.cache
# Plotting labels to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 131 weight(decay=0.0), 138 weight(decay=0.0005), 137 bias(decay=0.0)
# TensorBoard: WARNING ⚠️ TensorBoard graph visualization failure Tracing failed sanity checks!
# ERROR: Graphs differed across invocations!
# 	Graph diff:
# 		  graph(%self.1 : __torch__.ultralytics.nn.tasks.DetectionModel,
# 		        %x.1 : Tensor):
# 		    %model : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_21 : __torch__.ultralytics.nn.modules.head.Detect = prim::GetAttr[name="21"](%model)
# 		    %model.43 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_20 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="20"](%model.43)
# 		    %model.41 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_19 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="19"](%model.41)
# 		    %model.39 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_18 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="18"](%model.39)
# 		    %model.37 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_17 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="17"](%model.37)
# 		    %model.35 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_16 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="16"](%model.35)
# 		    %model.33 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_15 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="15"](%model.33)
# 		    %model.31 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_14 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="14"](%model.31)
# 		    %model.29 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_13 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="13"](%model.29)
# 		    %model.27 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_12 : __torch__.torch.nn.modules.upsampling.Upsample = prim::GetAttr[name="12"](%model.27)
# 		    %model.25 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_11 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="11"](%model.25)
# 		    %model.23 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_10 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="10"](%model.23)
# 		    %model.21 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_9 : __torch__.torch.nn.modules.upsampling.Upsample = prim::GetAttr[name="9"](%model.21)
# 		    %model.19 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_8 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="8"](%model.19)
# 		    %model.17 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="7"](%model.17)
# 		    %model.15 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_6 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="6"](%model.15)
# 		    %model.13 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="5"](%model.13)
# 		    %model.11 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_4 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="4"](%model.11)
# 		    %model.9 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="3"](%model.9)
# 		    %model.7 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_2.3 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="2"](%model.7)
# 		    %model.5 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_1.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="1"](%model.5)
# 		    %model.3 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_21.1 : __torch__.ultralytics.nn.modules.head.Detect = prim::GetAttr[name="21"](%model.3)
# 		    %cv3.1 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="cv3"](%_21.1)
# 		    %_2.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="2"](%cv3.1)
# 		    %_1.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="1"](%_2.1)
# 		    %_1.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="1"](%_1.1)
# 		    %act.1 : __torch__.torch.nn.modules.activation.SiLU = prim::GetAttr[name="act"](%_1.3)
# 		    %model.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_0.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="0"](%model.1)
# 		    %75 : int = prim::Constant[value=2](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %76 : int = prim::Constant[value=1](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %77 : bool = prim::Constant[value=0](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %78 : int = prim::Constant[value=0](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %79 : bool = prim::Constant[value=1](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.1 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_0.1)
# 		    %bias.275 : Tensor = prim::GetAttr[name="bias"](%conv.1)
# 		    %weight.277 : Tensor = prim::GetAttr[name="weight"](%conv.1)
# 		    %83 : int[] = prim::ListConstruct(%75, %75), scope: __module.model.0/__module.model.0.conv
# 		    %84 : int[] = prim::ListConstruct(%76, %76), scope: __module.model.0/__module.model.0.conv
# 		    %85 : int[] = prim::ListConstruct(%76, %76), scope: __module.model.0/__module.model.0.conv
# 		    %86 : int[] = prim::ListConstruct(%78, %78), scope: __module.model.0/__module.model.0.conv
# 		    %input.1 : Tensor = aten::_convolution(%x.1, %weight.277, %bias.275, %83, %84, %85, %77, %86, %76, %77, %79, %79, %79), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.3 : Tensor = aten::silu_(%input.1), scope: __module.model.0/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %89 : int = prim::Constant[value=2](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %90 : int = prim::Constant[value=1](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %91 : bool = prim::Constant[value=0](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %92 : int = prim::Constant[value=0](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %93 : bool = prim::Constant[value=1](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.3 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_1.5)
# 		    %bias.277 : Tensor = prim::GetAttr[name="bias"](%conv.3)
# 		    %weight.279 : Tensor = prim::GetAttr[name="weight"](%conv.3)
# 		    %97 : int[] = prim::ListConstruct(%89, %89), scope: __module.model.1/__module.model.1.conv
# 		    %98 : int[] = prim::ListConstruct(%90, %90), scope: __module.model.1/__module.model.1.conv
# 		    %99 : int[] = prim::ListConstruct(%90, %90), scope: __module.model.1/__module.model.1.conv
# 		    %100 : int[] = prim::ListConstruct(%92, %92), scope: __module.model.1/__module.model.1.conv
# 		    %input.5 : Tensor = aten::_convolution(%input.3, %weight.279, %bias.277, %97, %98, %99, %91, %100, %89, %91, %93, %93, %93), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.7 : Tensor = aten::silu_(%input.5), scope: __module.model.1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %103 : int = prim::Constant[value=2](), scope: __module.model.2 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %104 : bool = prim::Constant[value=1](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %105 : bool = prim::Constant[value=0](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %106 : int = prim::Constant[value=0](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %107 : int = prim::Constant[value=1](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %cv2.7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_2.3)
# 		    %m.3 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_2.3)
# 		    %_0.5 : __torch__.ultralytics.nn.modules.block.C3k = prim::GetAttr[name="0"](%m.3)
# 		    %cv1.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_2.3)
# 		    %conv.5 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.1)
# 		    %bias.279 : Tensor = prim::GetAttr[name="bias"](%conv.5)
# 		    %weight.281 : Tensor = prim::GetAttr[name="weight"](%conv.5)
# 		    %115 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %116 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %117 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %118 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %input.9 : Tensor = aten::_convolution(%input.7, %weight.281, %bias.279, %115, %116, %117, %105, %118, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %120 : Tensor = aten::silu_(%input.9), scope: __module.model.2/__module.model.2.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %121 : Tensor[] = aten::chunk(%120, %103, %107), scope: __module.model.2 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %122 : Tensor, %input.11 : Tensor = prim::ListUnpack(%121), scope: __module.model.2
# 		    %cv3.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv3"](%_0.5)
# 		    %cv2.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.5)
# 		    %m.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="m"](%_0.5)
# 		    %cv1.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.5)
# 		    %conv.7 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.3)
# 		    %bias.281 : Tensor = prim::GetAttr[name="bias"](%conv.7)
# 		    %weight.283 : Tensor = prim::GetAttr[name="weight"](%conv.7)
# 		    %131 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %132 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %133 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %134 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %input.13 : Tensor = aten::_convolution(%input.11, %weight.283, %bias.281, %131, %132, %133, %105, %134, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.15 : Tensor = aten::silu_(%input.13), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %_1.7 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="1"](%m.1)
# 		    %_0.3 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="0"](%m.1)
# 		    %cv2.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.3)
# 		    %cv1.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.3)
# 		    %conv.9 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.5)
# 		    %bias.283 : Tensor = prim::GetAttr[name="bias"](%conv.9)
# 		    %weight.285 : Tensor = prim::GetAttr[name="weight"](%conv.9)
# 		    %144 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %145 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %146 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %147 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %input.17 : Tensor = aten::_convolution(%input.15, %weight.285, %bias.283, %144, %145, %146, %105, %147, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.19 : Tensor = aten::silu_(%input.17), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %conv.11 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.1)
# 		    %bias.285 : Tensor = prim::GetAttr[name="bias"](%conv.11)
# 		    %weight.287 : Tensor = prim::GetAttr[name="weight"](%conv.11)
# 		    %153 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %154 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %155 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %156 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %input.21 : Tensor = aten::_convolution(%input.19, %weight.287, %bias.285, %153, %154, %155, %105, %156, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %158 : Tensor = aten::silu_(%input.21), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %input.23 : Tensor = aten::add(%input.15, %158, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:348:0
# 		    %cv2.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_1.7)
# 		    %cv1.7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_1.7)
# 		    %conv.13 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.7)
# 		    %bias.287 : Tensor = prim::GetAttr[name="bias"](%conv.13)
# 		    %weight.289 : Tensor = prim::GetAttr[name="weight"](%conv.13)
# 		    %165 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %166 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %167 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %168 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %input.25 : Tensor = aten::_convolution(%input.23, %weight.289, %bias.287, %165, %166, %167, %105, %168, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.27 : Tensor = aten::silu_(%input.25), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %conv.15 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.3)
# 		    %bias.289 : Tensor = prim::GetAttr[name="bias"](%conv.15)
# 		    %weight.291 : Tensor = prim::GetAttr[name="weight"](%conv.15)
# 		    %174 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %175 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %176 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %177 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %input.29 : Tensor = aten::_convolution(%input.27, %weight.291, %bias.289, %174, %175, %176, %105, %177, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %179 : Tensor = aten::silu_(%input.29), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %180 : Tensor = aten::add(%input.23, %179, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:348:0
# 		    %conv.17 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.5)
# 		    %bias.291 : Tensor = prim::GetAttr[name="bias"](%conv.17)
# 		    %weight.293 : Tensor = prim::GetAttr[name="weight"](%conv.17)
# 		    %184 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %185 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %186 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %187 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %input.31 : Tensor = aten::_convolution(%input.11, %weight.293, %bias.291, %184, %185, %186, %105, %187, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %189 : Tensor = aten::silu_(%input.31), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %190 : Tensor[] = prim::ListConstruct(%180, %189), scope: __module.model.2/__module.model.2.m.0
# 		    %input.33 : Tensor = aten::cat(%190, %107), scope: __module.model.2/__module.model.2.m.0 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:264:0
# 		    %conv.19 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv3.3)
# 		    %bias.293 : Tensor = prim::GetAttr[name="bias"](%conv.19)
# 		    %weight.295 : Tensor = prim::GetAttr[name="weight"](%conv.19)
# 		    %195 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %196 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %197 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %198 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %input.35 : Tensor = aten::_convolution(%input.33, %weight.295, %bias.293, %195, %196, %197, %105, %198, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %200 : Tensor = aten::silu_(%input.35), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %201 : Tensor[] = prim::ListConstruct(%122, %input.11, %200), scope: __module.model.2
# 		    %input.37 : Tensor = aten::cat(%201, %107), scope: __module.model.2 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:240:0
# 		    %conv.21 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.7)
# 		    %bias.295 : Tensor = prim::GetAttr[name="bias"](%conv.21)
# 		    %weight.297 : Tensor = prim::GetAttr[name="weight"](%conv.21)
# 		    %206 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %207 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %208 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %209 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %input.39 : Tensor = aten::_convolution(%input.37, %weight.297, %bias.295, %206, %207, %208, %105, %209, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.41 : Tensor = aten::silu_(%input.39), scope: __module.model.2/__module.model.2.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %212 : int = prim::Constant[value=2](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %213 : int = prim::Constant[value=1](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %214 : bool = prim::Constant[value=0](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %215 : int = prim::Constant[value=0](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %216 : int = prim::Constant[value=4](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %217 : bool = prim::Constant[value=1](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %conv.23 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_3)
# 		    %bias.297 : Tensor = prim::GetAttr[name="bias"](%conv.23)
# 		    %weight.299 : Tensor = prim::GetAttr[name="weight"](%conv.23)
# 		    %221 : int[] = prim::ListConstruct(%212, %212), scope: __module.model.3/__module.model.3.conv
# 		    %222 : int[] = prim::ListConstruct(%213, %213), scope: __module.model.3/__module.model.3.conv
# 		    %223 : int[] = prim::ListConstruct(%213, %213), scope: __module.model.3/__module.model.3.conv
# 		    %224 : int[] = prim::ListConstruct(%215, %215), scope: __module.model.3/__module.model.3.conv
# 		    %input.43 : Tensor = aten::_convolution(%input.41, %weight.299, %bias.297, %221, %222, %223, %214, %224, %216, %214, %217, %217, %217), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.45 : Tensor = aten::silu_(%input.43), scope: __module.model.3/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %227 : int = prim::Constant[value=2](), scope: __module.model.4 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %228 : bool = prim::Constant[value=1](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %229 : bool = prim::Constant[value=0](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %230 : int = prim::Constant[value=0](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %231 : int = prim::Constant[value=1](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %cv2.15 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_4)
# 		    %m.7 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_4)
# 		    %_0.9 : __torch__.ultralytics.nn.modules.block.C3k = prim::GetAttr[name="0"](%m.7)
# 		    %cv1.9 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_4)
# 		    %conv.25 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.9)
# 		    %bias.299 : Tensor = prim::GetAttr[name="bias"](%conv.25)
# 		    %weight.301 : Tensor = prim::GetAttr[name="weight"](%conv.25)
# 		    %239 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %240 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %241 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %242 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %input.47 : Tensor = aten::_convolution(%input.45, %weight.301, %bias.299, %239, %240, %241, %229, %242, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %244 : Tensor = aten::silu_(%input.47), scope: __module.model.4/__module.model.4.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %245 : Tensor[] = aten::chunk(%244, %227, %231), scope: __module.model.4 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:238:0
# 		    %246 : Tensor, %input.49 : Tensor = prim::ListUnpack(%245), scope: __module.model.4
# 		    %cv3.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv3"](%_0.9)
# 		    %cv2.13 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.9)
# 		    %m.5 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="m"](%_0.9)
# 		    %cv1.11 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.9)
# 		    %conv.27 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.11)
# 		    %bias.301 : Tensor = prim::GetAttr[name="bias"](%conv.27)
# 		    %weight.303 : Tensor = prim::GetAttr[name="weight"](%conv.27)
# 		    %255 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %256 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %257 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %258 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %input.51 : Tensor = aten::_convolution(%input.49, %weight.303, %bias.301, %255, %256, %257, %229, %258, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.53 : Tensor = aten::silu_(%input.51), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %_1.9 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="1"](%m.5)
# 		    %_0.7 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="0"](%m.5)
# 		    %cv2.9 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.7)
# 		    %cv1.13 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.7)
# 		    %conv.29 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.13)
# 		    %bias.303 : Tensor = prim::GetAttr[name="bias"](%conv.29)
# 		    %weight.305 : Tensor = prim::GetAttr[name="weight"](%conv.29)
# 		    %268 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %269 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %270 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %271 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %input.55 : Tensor = aten::_convolution(%input.53, %weight.305, %bias.303, %268, %269, %270, %229, %271, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.57 : Tensor = aten::silu_(%input.55), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %conv.31 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.9)
# 		    %bias.305 : Tensor = prim::GetAttr[name="bias"](%conv.31)
# 		    %weight.307 : Tensor = prim::GetAttr[name="weight"](%conv.31)
# 		    %277 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %278 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %279 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %280 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %input.59 : Tensor = aten::_convolution(%input.57, %weight.307, %bias.305, %277, %278, %279, %229, %280, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %282 : Tensor = aten::silu_(%input.59), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %input.61 : Tensor = aten::add(%input.53, %282, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:348:0
# 		    %cv2.11 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_1.9)
# 		    %cv1.15 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_1.9)
# 		    %conv.33 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.15)
# 		    %bias.307 : Tensor = prim::GetAttr[name="bias"](%conv.33)
# 		    %weight.309 : Tensor = prim::GetAttr[name="weight"](%conv.33)
# 		    %289 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %290 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %291 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %292 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %input.63 : Tensor = aten::_convolution(%input.61, %weight.309, %bias.307, %289, %290, %291, %229, %292, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %input.65 : Tensor = aten::silu_(%input.63), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %conv.35 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.11)
# 		    %bias.309 : Tensor = prim::GetAttr[name="bias"](%conv.35)
# 		    %weight.311 : Tensor = prim::GetAttr[name="weight"](%conv.35)
# 		    %298 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %299 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %300 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %301 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %input.67 : Tensor = aten::_convolution(%input.65, %weight.311, %bias.309, %298, %299, %300, %229, %301, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %303 : Tensor = aten::silu_(%input.67), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %304 : Tensor = aten::add(%input.61, %303, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:348:0
# 		    %conv.37 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.13)
# 		    %bias.311 : Tensor = prim::GetAttr[name="bias"](%conv.37)
# 		    %weight.313 : Tensor = prim::GetAttr[name="weight"](%conv.37)
# 		    %308 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %309 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %310 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %311 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %input.69 : Tensor = aten::_convolution(%input.49, %weight.313, %bias.311, %308, %309, %310, %229, %311, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv # /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:454:0
# 		    %313 : Tensor = aten::silu_(%input.69), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2104:0
# 		    %314 : Tensor[] = prim::ListConstruct(%304, %313), scope: __module.model.4/__module.model.4.m.0
# ...
# 		    %x2y2 : Tensor = aten::add(%anchor_points, %rb, %1808), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/utils/tal.py:352:0
# 		    %2099 : Tensor = aten::add(%x1y1, %x2y2, %1808), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/utils/tal.py:354:0
# 		    %c_xy : Tensor = aten::div(%2099, %1797), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/utils/tal.py:354:0
# 		    %wh : Tensor = aten::sub(%x2y2, %x1y1, %1808), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/utils/tal.py:355:0
# 		    %2102 : Tensor[] = prim::ListConstruct(%c_xy, %wh), scope: __module.model.21
# 		    %2103 : Tensor = aten::cat(%2102, %1808), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/utils/tal.py:356:0
# 		    %dbox : Tensor = aten::mul(%2103, %1796), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/head.py:129:0
# 		    %2105 : Tensor = aten::sigmoid(%cls), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/head.py:131:0
# 		    %2106 : Tensor[] = prim::ListConstruct(%dbox, %2105), scope: __module.model.21
# 		    %2107 : Tensor = aten::cat(%2106, %1808), scope: __module.model.21 # /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/head.py:131:0
# 		    return (%2107)
# 	First diverging operator:
# 	Node diff:
# 		- %model : __torch__.torch.nn.modules.container.___torch_mangle_11941.Sequential = prim::GetAttr[name="model"](%self.1)
# 		?                                                                ^^ ^
# 		+ %model : __torch__.torch.nn.modules.container.___torch_mangle_12433.Sequential = prim::GetAttr[name="model"](%self.1)
# 		?                                                                ^ ^^
#
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12/yolov12/runs/detect/train
# Starting training for 250 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/21 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[11], line 7
#       4 model = YOLO('yolov12m.yaml')
#       6 # Train the model using RGB data
# ----> 7 results = model.train(
#       8     data=f'{dataset_path}/data.yaml',
#       9     epochs=250
#      10 )
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/engine/model.py:808, in Model.train(self, trainer, **kwargs)
#     805     self.model = self.trainer.model
#     807 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 808 self.trainer.train()
#     809 # Update model and cfg after training
#     810 if RANK in {-1, 0}:
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/engine/trainer.py:207, in BaseTrainer.train(self)
#     204         ddp_cleanup(self, str(file))
#     206 else:
# --> 207     self._do_train(world_size)
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/engine/trainer.py:381, in BaseTrainer._do_train(self, world_size)
#     379 with autocast(self.amp):
#     380     batch = self.preprocess_batch(batch)
# --> 381     self.loss, self.loss_items = self.model(batch)
#     382     if RANK != -1:
#     383         self.loss *= world_size
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/tasks.py:110, in BaseModel.forward(self, x, *args, **kwargs)
#      96 """
#      97 Perform forward pass of the model for either training or inference.
#      98
#    (...)
#     107     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     108 """
#     109 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 110     return self.loss(x, *args, **kwargs)
#     111 return self.predict(x, *args, **kwargs)
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/tasks.py:291, in BaseModel.loss(self, batch, preds)
#     288 if getattr(self, "criterion", None) is None:
#     289     self.criterion = self.init_criterion()
# --> 291 preds = self.forward(batch["img"]) if preds is None else preds
#     292 return self.criterion(preds, batch)
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/tasks.py:111, in BaseModel.forward(self, x, *args, **kwargs)
#     109 if isinstance(x, dict):  # for cases of training and validating while training.
#     110     return self.loss(x, *args, **kwargs)
# --> 111 return self.predict(x, *args, **kwargs)
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/tasks.py:129, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     127 if augment:
#     128     return self._predict_augment(x)
# --> 129 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/tasks.py:150, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     148 if profile:
#     149     self._profile_one_layer(m, x, dt)
# --> 150 x = m(x)  # run
#     151 y.append(x if m.i in self.save else None)  # save output
#     152 if visualize:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1366, in A2C2f.forward(self, x)
#    1364 """Forward pass through R-ELAN layer."""
#    1365 y = [self.cv1(x)]
# -> 1366 y.extend(m(y[-1]) for m in self.m)
#    1367 if self.gamma is not None:
#    1368     return x + self.gamma.view(1, -1, 1, 1) * self.cv2(torch.cat(y, 1))
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1366, in <genexpr>(.0)
#    1364 """Forward pass through R-ELAN layer."""
#    1365 y = [self.cv1(x)]
# -> 1366 y.extend(m(y[-1]) for m in self.m)
#    1367 if self.gamma is not None:
#    1368     return x + self.gamma.view(1, -1, 1, 1) * self.cv2(torch.cat(y, 1))
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1310, in ABlock.forward(self, x)
#    1308 def forward(self, x):
#    1309     """Executes a forward pass through ABlock, applying area-attention and feed-forward layers to the input tensor."""
# -> 1310     x = x + self.attn(x)
#    1311     x = x + self.mlp(x)
#    1312     return x
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/block.py:1222, in AAttn.forward(self, x)
#    1219 B, C, H, W = x.shape
#    1220 N = H * W
# -> 1222 qk = self.qk(x).flatten(2).transpose(1, 2)
#    1223 v = self.v(x)
#    1224 pp = self.pe(v)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/ultralytics/nn/modules/conv.py:51, in Conv.forward(self, x)
#      49 def forward(self, x):
#      50     """Apply convolution, batch normalization and activation to input tensor."""
# ---> 51     return self.act(self.bn(self.conv(x)))
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/batchnorm.py:176, in _BatchNorm.forward(self, input)
#     169     bn_training = (self.running_mean is None) and (self.running_var is None)
#     171 r"""
#     172 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     173 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     174 used for normalization (i.e. in eval mode when buffers are not None).
#     175 """
# --> 176 return F.batch_norm(
#     177     input,
#     178     # If buffers are not to be tracked, ensure that they won't be updated
#     179     self.running_mean
#     180     if not self.training or self.track_running_stats
#     181     else None,
#     182     self.running_var if not self.training or self.track_running_stats else None,
#     183     self.weight,
#     184     self.bias,
#     185     bn_training,
#     186     exponential_average_factor,
#     187     self.eps,
#     188 )
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2512, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2509 if training:
#    2510     _verify_batch_size(input.size())
# -> 2512 return torch.batch_norm(
#    2513     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2514 )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 26.00 MiB. GPU 0 has a total capacity of 23.51 GiB of which 28.56 MiB is free. Process 630688 has 1.37 GiB memory in use. Including non-PyTorch memory, this process has 5.45 GiB memory in use. Process 635064 has 854.00 MiB memory in use. Process 647022 has 15.09 GiB memory in use. Of the allocated memory 4.55 GiB is allocated by PyTorch, and 121.95 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
