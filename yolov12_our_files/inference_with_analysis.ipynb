# %%
# %pip install supervision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# Requirement already satisfied: supervision in /home/omtalmo/.local/lib/python3.10/site-packages (0.25.1)
# Requirement already satisfied: contourpy>=1.0.7 in /home/omtalmo/.local/lib/python3.10/site-packages (from supervision) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/lib/python3/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from supervision) (3.10.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /home/omtalmo/.local/lib/python3.10/site-packages (from supervision) (4.11.0.86)
# Requirement already satisfied: pillow>=9.4 in /home/omtalmo/.local/lib/python3.10/site-packages (from supervision) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from supervision) (6.0.1)
# Requirement already satisfied: requests>=2.26.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /home/omtalmo/.local/lib/python3.10/site-packages (from supervision) (1.15.2)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.10/dist-packages (from supervision) (4.66.4)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.0->supervision) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.0->supervision) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.0->supervision) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.0->supervision) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.0->supervision) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->supervision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests>=2.26.0->supervision) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/omtalmo/.local/lib/python3.10/site-packages (from requests>=2.26.0->supervision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.26.0->supervision) (2020.6.20)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Define paths and describe model

# %%
import os
import cv2
import supervision as sv
from pathlib import Path
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm  # For progress bar
from ultralytics import YOLO
import shutil
import tkinter as tk
from tkinter import simpledialog
import datetime


# -------------  Change these and run all cells -------------------

dir_name = "custom_ar_hyp_tuning_pt_retraining_with_hyp_tuning_imgsz=1280" 
train_dir = "/home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12/runs/detect/train42"
model = YOLO("/home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12/runs/detect/train42/weights/best.pt")
dataset_path = "/home/omtalmo/Olaf_TTK4265/Poles/rgb"
output_dir = f"/home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/results/{dir_name}"

# -------------------------------------------------------------------


# Local paths, list creation and folder creation
os.makedirs(output_dir, exist_ok=True)
valid_label_dir = f"{dataset_path}/labels/valid"

test_image_dir = f"{dataset_path}/images/test"
test_images = []
for img in os.listdir(test_image_dir):
    if img.upper().endswith('.PNG') or img.lower().endswith(('.png', '.jpg', '.jpeg')):
        test_images.append(os.path.join(test_image_dir, img))

valid_image_dir = f"{dataset_path}/images/valid"
valid_images = []
for img in os.listdir(valid_image_dir):
    if img.upper().endswith('.PNG') or img.lower().endswith(('.png', '.jpg', '.jpeg')):
        valid_images.append(os.path.join(valid_image_dir, img))

# Copy the contents of the training directory to the output directory
train_output_dir = os.path.join(output_dir, "train_results")
os.makedirs(train_output_dir, exist_ok=True)

# Copy the contents of the training directory
print(f"Copying training results from {train_dir} to {train_output_dir}...")
for item in os.listdir(train_dir):
    s = os.path.join(train_dir, item)
    d = os.path.join(train_output_dir, item)
    if os.path.isdir(s):
        shutil.copytree(s, d, dirs_exist_ok=True)
    else:
        shutil.copy2(s, d)
print("Training results copied successfully!")

# Create a pop-up window to get the run description
# …existing imports and variable definitions above…

def get_run_description():
    """
    Pop up a Tk window to collect a multi-line description.
    If running headless (no $DISPLAY), fall back to console input.
    Always writes run_description.txt in output_dir.
    """
    # capture timestamp early so both branches can use it
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    try:
        # -- GUI branch --
        root = tk.Tk()
        root.title("Run Description")
        root.geometry("600x400")

        # Instruction label
        tk.Label(
            root,
            text="Beskriv modellen. Eller bare spam tastaturet, ditt valg:",
            font=("Arial", 12),
            pady=10,
            padx=10
        ).pack(fill="x")

        # Scrollable text box
        text_frame = tk.Frame(root)
        text_frame.pack(fill="both", expand=True, padx=20, pady=10)
        scrollbar = tk.Scrollbar(text_frame)
        scrollbar.pack(side="right", fill="y")
        text_box = tk.Text(
            text_frame,
            height=15,
            width=70,
            wrap="word",
            yscrollcommand=scrollbar.set,
            font=("Arial", 11)
        )
        text_box.pack(side="left", fill="both", expand=True)
        scrollbar.config(command=text_box.yview)
        text_box.focus_set()

        # StringVar to collect result
        description_var = tk.StringVar()

        # Button handlers
        def save_description():
            description_var.set(text_box.get("1.0", "end-1c"))
            root.destroy()

        def cancel():
            description_var.set("")
            root.destroy()

        # Buttons
        btn_frame = tk.Frame(root)
        btn_frame.pack(pady=15)
        tk.Button(
            btn_frame,
            text="Save Description",
            command=save_description,
            font=("Arial", 11),
            width=15,
            bg="#4CAF50",
            fg="white"
        ).pack(side="left", padx=10)
        tk.Button(
            btn_frame,
            text="Cancel",
            command=cancel,
            font=("Arial", 11),
            width=10
        ).pack(side="left", padx=10)

        # Wait for user action
        root.mainloop()
        description = description_var.get().strip() or "No description provided"

    except tk.TclError:
        # -- Headless branch --
        print("GUI not available, falling back to console input.")
        raw = input(
            "Enter run description (empty → 'No description provided'): "
        ).strip()
        description = raw or "No description provided"

    # Write out description file
    desc_file = os.path.join(output_dir, "run_description.txt")
    with open(desc_file, "w") as f:
        f.write(f"Run Description - {timestamp}\n")
        f.write(f"Dir Name:    {dir_name}\n")
        f.write(f"Model:       {model.ckpt_path}\n\n")
        f.write("Description:\n")
        f.write(description + "\n")

    print(f"Description saved to {desc_file}")
    return description

# Invoke it
run_description = get_run_description()
# Out:
# Copying training results from /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/yolov12/yolov12/runs/detect/train42 to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/results/custom_ar_hyp_tuning_pt_retraining_with_hyp_tuning_imgsz=1280/train_results...
# Training results copied successfully!
# Description saved to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/results/custom_ar_hyp_tuning_pt_retraining_with_hyp_tuning_imgsz=1280/run_description.txt

# %%
model.predict(
    imgsz= 1280,
    source=f"{dataset_path}/images/test",
    project="SAVE_FOLDER",
    name="retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning",
    save_txt=True,
    save_conf=True # <--- This adds the probability of each predicted box
    )
# Out:
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 46 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[179, 186, 192],
#          [179, 186, 192],
#          [179, 186, 192],
#          ...,
#          [181, 195, 200],
#          [180, 194, 199],
#          [180, 194, 199]],
#
#         [[179, 186, 192],
#          [179, 186, 192],
#          [179, 186, 192],
#          ...,
#          [180, 194, 199],
#          [179, 193, 198],
#          [180, 194, 199]],
#
#         [[182, 187, 193],
#          [182, 187, 193],
#          [182, 187, 193],
#          ...,
#          [182, 194, 199],
#          [180, 192, 197],
#          [180, 192, 197]],
#
#         ...,
#
#         [[ 74,  76,  83],
#          [ 74,  76,  83],
#          [ 74,  76,  83],
#          ...,
#          [ 66,  70,  79],
#          [ 66,  70,  79],
#          [ 66,  70,  79]],
#
#         [[ 75,  77,  84],
#          [ 75,  77,  84],
#          [ 75,  77,  84],
#          ...,
#          [ 66,  70,  79],
#          [ 66,  70,  79],
#          [ 66,  70,  79]],
#
#         [[ 75,  77,  84],
#          [ 75,  77,  84],
#          [ 75,  77,  84],
#          ...,
#          [ 66,  70,  79],
#          [ 66,  70,  79],
#          [ 66,  70,  79]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000005.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 11.66391372680664, 'inference': 5.2814483642578125, 'postprocess': 0.5230903625488281},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[177, 185, 194],
#          [177, 185, 194],
#          [177, 185, 194],
#          ...,
#          [184, 192, 196],
#          [183, 191, 195],
#          [181, 189, 193]],
#
#         [[178, 186, 195],
#          [178, 186, 195],
#          [177, 185, 194],
#          ...,
#          [184, 192, 196],
#          [183, 191, 195],
#          [181, 189, 193]],
#
#         [[183, 187, 196],
#          [182, 186, 195],
#          [181, 185, 194],
#          ...,
#          [184, 192, 196],
#          [183, 191, 195],
#          [183, 191, 195]],
#
#         ...,
#
#         [[ 73,  76,  81],
#          [ 73,  76,  81],
#          [ 73,  76,  81],
#          ...,
#          [ 67,  67,  79],
#          [ 67,  67,  79],
#          [ 67,  67,  79]],
#
#         [[ 73,  76,  81],
#          [ 73,  76,  81],
#          [ 73,  76,  81],
#          ...,
#          [ 68,  68,  80],
#          [ 68,  68,  80],
#          [ 68,  68,  80]],
#
#         [[ 73,  76,  81],
#          [ 73,  76,  81],
#          [ 73,  76,  81],
#          ...,
#          [ 68,  68,  80],
#          [ 68,  68,  80],
#          [ 68,  68,  80]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000115.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.5777816772460938, 'inference': 5.234956741333008, 'postprocess': 0.5283355712890625},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[165, 174, 180],
#          [165, 174, 180],
#          [166, 173, 179],
#          ...,
#          [173, 178, 184],
#          [178, 184, 188],
#          [180, 186, 190]],
#
#         [[167, 176, 182],
#          [167, 176, 182],
#          [167, 174, 180],
#          ...,
#          [174, 179, 185],
#          [176, 182, 186],
#          [178, 184, 188]],
#
#         [[167, 174, 180],
#          [169, 176, 182],
#          [169, 174, 180],
#          ...,
#          [175, 180, 186],
#          [174, 180, 184],
#          [173, 179, 183]],
#
#         ...,
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 75,  75,  82],
#          ...,
#          [ 56,  57,  67],
#          [ 56,  56,  68],
#          [ 57,  57,  69]],
#
#         [[ 77,  77,  84],
#          [ 77,  77,  84],
#          [ 76,  76,  83],
#          ...,
#          [ 57,  58,  68],
#          [ 57,  57,  69],
#          [ 59,  59,  71]],
#
#         [[ 77,  77,  84],
#          [ 77,  77,  84],
#          [ 76,  76,  83],
#          ...,
#          [ 57,  58,  68],
#          [ 57,  57,  69],
#          [ 59,  59,  71]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000260.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.4499893188476562, 'inference': 4.50897216796875, 'postprocess': 0.40030479431152344},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[171, 176, 182],
#          [172, 177, 183],
#          [176, 181, 187],
#          ...,
#          [167, 174, 180],
#          [167, 174, 180],
#          [167, 174, 180]],
#
#         [[166, 171, 177],
#          [166, 171, 177],
#          [169, 174, 180],
#          ...,
#          [167, 174, 180],
#          [167, 174, 180],
#          [167, 174, 180]],
#
#         [[172, 177, 183],
#          [168, 173, 179],
#          [167, 172, 178],
#          ...,
#          [169, 176, 182],
#          [169, 176, 182],
#          [169, 176, 182]],
#
#         ...,
#
#         [[ 71,  70,  80],
#          [ 71,  70,  80],
#          [ 71,  70,  80],
#          ...,
#          [ 59,  58,  68],
#          [ 59,  58,  68],
#          [ 59,  58,  68]],
#
#         [[ 72,  71,  81],
#          [ 72,  71,  81],
#          [ 72,  71,  81],
#          ...,
#          [ 61,  60,  70],
#          [ 61,  60,  70],
#          [ 61,  60,  70]],
#
#         [[ 73,  72,  82],
#          [ 73,  72,  82],
#          [ 73,  72,  82],
#          ...,
#          [ 61,  60,  70],
#          [ 61,  60,  70],
#          [ 61,  60,  70]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000265.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.466440200805664, 'inference': 4.45103645324707, 'postprocess': 0.41747093200683594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[167, 176, 182],
#          [167, 176, 182],
#          [167, 176, 182],
#          ...,
#          [170, 177, 183],
#          [170, 177, 183],
#          [170, 177, 183]],
#
#         [[165, 174, 180],
#          [165, 174, 180],
#          [165, 174, 180],
#          ...,
#          [169, 176, 182],
#          [169, 176, 182],
#          [169, 176, 182]],
#
#         [[167, 176, 182],
#          [167, 176, 182],
#          [167, 176, 182],
#          ...,
#          [170, 177, 183],
#          [170, 177, 183],
#          [170, 177, 183]],
#
#         ...,
#
#         [[ 72,  73,  78],
#          [ 72,  73,  78],
#          [ 72,  73,  78],
#          ...,
#          [ 61,  60,  70],
#          [ 61,  60,  70],
#          [ 61,  60,  70]],
#
#         [[ 73,  74,  79],
#          [ 73,  74,  79],
#          [ 73,  74,  79],
#          ...,
#          [ 62,  61,  71],
#          [ 62,  61,  71],
#          [ 62,  61,  71]],
#
#         [[ 73,  74,  79],
#          [ 73,  74,  79],
#          [ 73,  74,  79],
#          ...,
#          [ 62,  61,  71],
#          [ 62,  61,  71],
#          [ 62,  61,  71]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000280.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.3899078369140625, 'inference': 4.379749298095703, 'postprocess': 0.6978511810302734},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[169, 175, 179],
#          [169, 175, 179],
#          [168, 174, 178],
#          ...,
#          [170, 177, 183],
#          [170, 177, 183],
#          [170, 177, 183]],
#
#         [[168, 174, 178],
#          [169, 175, 179],
#          [168, 174, 178],
#          ...,
#          [169, 176, 182],
#          [169, 176, 182],
#          [169, 176, 182]],
#
#         [[168, 174, 178],
#          [169, 175, 179],
#          [168, 174, 178],
#          ...,
#          [170, 177, 183],
#          [170, 177, 183],
#          [170, 177, 183]],
#
#         ...,
#
#         [[ 72,  73,  78],
#          [ 72,  73,  78],
#          [ 72,  73,  78],
#          ...,
#          [ 61,  60,  70],
#          [ 61,  60,  70],
#          [ 61,  60,  70]],
#
#         [[ 73,  74,  79],
#          [ 73,  74,  79],
#          [ 73,  74,  79],
#          ...,
#          [ 62,  61,  71],
#          [ 62,  61,  71],
#          [ 62,  61,  71]],
#
#         [[ 73,  74,  79],
#          [ 73,  74,  79],
#          [ 73,  74,  79],
#          ...,
#          [ 62,  61,  71],
#          [ 62,  61,  71],
#          [ 62,  61,  71]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000285.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.4187564849853516, 'inference': 4.336357116699219, 'postprocess': 0.38909912109375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[160, 173, 181],
#          [160, 173, 181],
#          [161, 173, 178],
#          ...,
#          [169, 178, 184],
#          [172, 181, 187],
#          [171, 180, 186]],
#
#         [[163, 176, 184],
#          [163, 176, 184],
#          [163, 175, 180],
#          ...,
#          [165, 174, 180],
#          [168, 177, 183],
#          [167, 176, 182]],
#
#         [[165, 175, 179],
#          [165, 175, 179],
#          [163, 172, 178],
#          ...,
#          [164, 173, 179],
#          [164, 173, 179],
#          [162, 171, 177]],
#
#         ...,
#
#         [[ 70,  72,  79],
#          [ 70,  72,  79],
#          [ 70,  72,  79],
#          ...,
#          [ 63,  62,  72],
#          [ 63,  62,  72],
#          [ 63,  62,  72]],
#
#         [[ 71,  73,  80],
#          [ 71,  73,  80],
#          [ 71,  73,  80],
#          ...,
#          [ 64,  63,  73],
#          [ 64,  63,  73],
#          [ 64,  63,  73]],
#
#         [[ 71,  73,  80],
#          [ 71,  73,  80],
#          [ 71,  73,  80],
#          ...,
#          [ 64,  63,  73],
#          [ 64,  63,  73],
#          [ 64,  63,  73]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000315.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.4290084838867188, 'inference': 4.302024841308594, 'postprocess': 0.40340423583984375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[169, 177, 186],
#          [168, 176, 185],
#          [168, 176, 185],
#          ...,
#          [171, 179, 183],
#          [171, 179, 183],
#          [171, 179, 183]],
#
#         [[169, 177, 186],
#          [168, 176, 185],
#          [168, 176, 185],
#          ...,
#          [171, 179, 183],
#          [171, 179, 183],
#          [171, 179, 183]],
#
#         [[169, 177, 186],
#          [168, 176, 185],
#          [168, 176, 185],
#          ...,
#          [171, 179, 183],
#          [171, 179, 183],
#          [171, 179, 183]],
#
#         ...,
#
#         [[ 74,  76,  83],
#          [ 74,  76,  83],
#          [ 73,  75,  82],
#          ...,
#          [ 63,  64,  74],
#          [ 63,  64,  74],
#          [ 63,  64,  74]],
#
#         [[ 75,  77,  84],
#          [ 74,  76,  83],
#          [ 74,  76,  83],
#          ...,
#          [ 63,  64,  74],
#          [ 63,  64,  74],
#          [ 63,  64,  74]],
#
#         [[ 75,  77,  84],
#          [ 75,  77,  84],
#          [ 74,  76,  83],
#          ...,
#          [ 63,  64,  74],
#          [ 63,  64,  74],
#          [ 63,  64,  74]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000485.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.395153045654297, 'inference': 4.317998886108398, 'postprocess': 0.7224082946777344},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[174, 179, 185],
#          [174, 179, 185],
#          [173, 178, 184],
#          ...,
#          [172, 179, 185],
#          [174, 181, 187],
#          [176, 183, 189]],
#
#         [[172, 177, 183],
#          [172, 177, 183],
#          [173, 178, 184],
#          ...,
#          [173, 180, 186],
#          [173, 180, 186],
#          [174, 181, 187]],
#
#         [[172, 177, 183],
#          [172, 177, 183],
#          [173, 178, 184],
#          ...,
#          [173, 180, 186],
#          [172, 179, 185],
#          [172, 179, 185]],
#
#         ...,
#
#         [[ 75,  75,  82],
#          [ 75,  75,  82],
#          [ 75,  75,  82],
#          ...,
#          [ 64,  63,  73],
#          [ 64,  63,  73],
#          [ 64,  63,  73]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 64,  63,  73],
#          [ 64,  63,  73],
#          [ 64,  63,  73]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 64,  63,  73],
#          [ 64,  63,  73],
#          [ 64,  63,  73]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000510.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.386808395385742, 'inference': 4.301786422729492, 'postprocess': 0.3902912139892578},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[173, 180, 186],
#          [173, 180, 186],
#          [170, 177, 183],
#          ...,
#          [170, 177, 183],
#          [170, 177, 183],
#          [170, 177, 183]],
#
#         [[172, 179, 185],
#          [173, 180, 186],
#          [173, 180, 186],
#          ...,
#          [170, 177, 183],
#          [170, 177, 183],
#          [170, 177, 183]],
#
#         [[169, 174, 180],
#          [175, 180, 186],
#          [178, 183, 189],
#          ...,
#          [170, 177, 183],
#          [170, 177, 183],
#          [170, 177, 183]],
#
#         ...,
#
#         [[ 73,  74,  79],
#          [ 73,  74,  79],
#          [ 72,  73,  78],
#          ...,
#          [ 61,  62,  72],
#          [ 61,  62,  72],
#          [ 61,  62,  72]],
#
#         [[ 75,  76,  81],
#          [ 75,  76,  81],
#          [ 73,  74,  79],
#          ...,
#          [ 61,  62,  72],
#          [ 61,  62,  72],
#          [ 61,  62,  72]],
#
#         [[ 75,  76,  81],
#          [ 75,  76,  81],
#          [ 73,  74,  79],
#          ...,
#          [ 61,  62,  72],
#          [ 61,  62,  72],
#          [ 61,  62,  72]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_000570.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.3927688598632812, 'inference': 4.499197006225586, 'postprocess': 0.4379749298095703},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[165, 173, 177],
#          [167, 175, 179],
#          [166, 174, 178],
#          ...,
#          [181, 187, 196],
#          [181, 187, 196],
#          [179, 185, 194]],
#
#         [[165, 173, 177],
#          [167, 175, 179],
#          [166, 174, 178],
#          ...,
#          [180, 186, 195],
#          [180, 186, 195],
#          [178, 184, 193]],
#
#         [[165, 173, 177],
#          [167, 175, 179],
#          [166, 174, 178],
#          ...,
#          [179, 185, 194],
#          [179, 185, 194],
#          [179, 185, 194]],
#
#         ...,
#
#         [[ 62,  72,  71],
#          [ 63,  73,  72],
#          [ 62,  72,  71],
#          ...,
#          [ 66,  64,  78],
#          [ 66,  64,  78],
#          [ 66,  64,  78]],
#
#         [[ 63,  73,  72],
#          [ 63,  73,  72],
#          [ 62,  72,  71],
#          ...,
#          [ 66,  64,  78],
#          [ 66,  64,  78],
#          [ 66,  64,  78]],
#
#         [[ 63,  73,  72],
#          [ 64,  74,  73],
#          [ 62,  72,  71],
#          ...,
#          [ 66,  64,  78],
#          [ 66,  64,  78],
#          [ 66,  64,  78]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001015.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7053356170654297, 'inference': 4.332304000854492, 'postprocess': 0.6957054138183594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[171, 177, 181],
#          [171, 177, 181],
#          [171, 177, 181],
#          ...,
#          [181, 191, 195],
#          [182, 192, 196],
#          [183, 193, 197]],
#
#         [[171, 177, 181],
#          [171, 177, 181],
#          [171, 177, 181],
#          ...,
#          [179, 189, 193],
#          [179, 189, 193],
#          [179, 189, 193]],
#
#         [[171, 177, 181],
#          [171, 177, 181],
#          [171, 177, 181],
#          ...,
#          [175, 185, 189],
#          [175, 185, 189],
#          [175, 185, 189]],
#
#         ...,
#
#         [[ 70,  72,  79],
#          [ 70,  72,  79],
#          [ 69,  71,  78],
#          ...,
#          [ 66,  69,  74],
#          [ 66,  69,  74],
#          [ 66,  69,  74]],
#
#         [[ 71,  73,  80],
#          [ 71,  73,  80],
#          [ 70,  72,  79],
#          ...,
#          [ 66,  69,  74],
#          [ 66,  69,  74],
#          [ 66,  69,  74]],
#
#         [[ 73,  75,  82],
#          [ 71,  73,  80],
#          [ 70,  72,  79],
#          ...,
#          [ 66,  69,  74],
#          [ 66,  69,  74],
#          [ 66,  69,  74]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001305.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.747774124145508, 'inference': 4.685878753662109, 'postprocess': 1.0099411010742188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[165, 177, 182],
#          [165, 177, 182],
#          [167, 176, 182],
#          ...,
#          [182, 187, 193],
#          [183, 188, 194],
#          [185, 190, 196]],
#
#         [[165, 177, 182],
#          [165, 177, 182],
#          [167, 176, 182],
#          ...,
#          [182, 187, 193],
#          [183, 188, 194],
#          [185, 190, 196]],
#
#         [[165, 177, 182],
#          [165, 177, 182],
#          [167, 176, 182],
#          ...,
#          [182, 187, 193],
#          [183, 188, 194],
#          [185, 190, 196]],
#
#         ...,
#
#         [[ 70,  74,  76],
#          [ 70,  74,  76],
#          [ 69,  73,  75],
#          ...,
#          [ 66,  69,  74],
#          [ 66,  69,  74],
#          [ 66,  69,  74]],
#
#         [[ 71,  75,  77],
#          [ 71,  75,  77],
#          [ 70,  74,  76],
#          ...,
#          [ 66,  69,  74],
#          [ 66,  69,  74],
#          [ 66,  69,  74]],
#
#         [[ 73,  77,  79],
#          [ 71,  75,  77],
#          [ 70,  74,  76],
#          ...,
#          [ 66,  69,  74],
#          [ 66,  69,  74],
#          [ 66,  69,  74]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001315.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.740621566772461, 'inference': 4.416942596435547, 'postprocess': 0.3993511199951172},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[170, 178, 182],
#          [169, 177, 181],
#          [170, 178, 182],
#          ...,
#          [185, 193, 197],
#          [180, 188, 192],
#          [176, 184, 188]],
#
#         [[169, 177, 181],
#          [167, 175, 179],
#          [169, 177, 181],
#          ...,
#          [184, 192, 196],
#          [181, 189, 193],
#          [180, 188, 192]],
#
#         [[172, 178, 182],
#          [171, 177, 181],
#          [172, 178, 182],
#          ...,
#          [181, 189, 193],
#          [184, 192, 196],
#          [187, 195, 199]],
#
#         ...,
#
#         [[ 69,  70,  75],
#          [ 69,  70,  75],
#          [ 69,  70,  75],
#          ...,
#          [ 70,  69,  79],
#          [ 70,  69,  79],
#          [ 70,  69,  79]],
#
#         [[ 69,  70,  75],
#          [ 69,  70,  75],
#          [ 69,  70,  75],
#          ...,
#          [ 70,  69,  79],
#          [ 70,  69,  79],
#          [ 70,  69,  79]],
#
#         [[ 69,  70,  75],
#          [ 69,  70,  75],
#          [ 69,  70,  75],
#          ...,
#          [ 70,  69,  79],
#          [ 70,  69,  79],
#          [ 70,  69,  79]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001345.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7773380279541016, 'inference': 4.686832427978516, 'postprocess': 0.4558563232421875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[175, 181, 185],
#          [179, 185, 189],
#          [185, 191, 195],
#          ...,
#          [185, 193, 197],
#          [183, 191, 195],
#          [185, 193, 197]],
#
#         [[176, 182, 186],
#          [178, 184, 188],
#          [179, 185, 189],
#          ...,
#          [185, 193, 197],
#          [184, 192, 196],
#          [186, 194, 198]],
#
#         [[179, 185, 189],
#          [178, 184, 188],
#          [174, 180, 184],
#          ...,
#          [184, 192, 196],
#          [185, 193, 197],
#          [183, 191, 195]],
#
#         ...,
#
#         [[ 71,  73,  80],
#          [ 71,  73,  80],
#          [ 71,  73,  80],
#          ...,
#          [ 68,  69,  79],
#          [ 68,  69,  79],
#          [ 68,  69,  79]],
#
#         [[ 73,  75,  82],
#          [ 73,  75,  82],
#          [ 73,  75,  82],
#          ...,
#          [ 68,  69,  79],
#          [ 68,  69,  79],
#          [ 68,  69,  79]],
#
#         [[ 73,  75,  82],
#          [ 73,  75,  82],
#          [ 73,  75,  82],
#          ...,
#          [ 68,  69,  79],
#          [ 68,  69,  79],
#          [ 68,  69,  79]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001435.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.8154850006103516, 'inference': 4.75311279296875, 'postprocess': 0.47206878662109375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[176, 186, 190],
#          [176, 186, 190],
#          [176, 186, 190],
#          ...,
#          [191, 199, 203],
#          [192, 200, 204],
#          [192, 200, 204]],
#
#         [[175, 185, 189],
#          [175, 185, 189],
#          [175, 185, 189],
#          ...,
#          [188, 196, 200],
#          [190, 198, 202],
#          [190, 198, 202]],
#
#         [[179, 187, 191],
#          [178, 186, 190],
#          [179, 185, 189],
#          ...,
#          [187, 195, 199],
#          [188, 196, 200],
#          [188, 196, 200]],
#
#         ...,
#
#         [[ 78,  79,  84],
#          [ 78,  79,  84],
#          [ 77,  78,  83],
#          ...,
#          [ 71,  74,  79],
#          [ 73,  76,  81],
#          [ 74,  77,  82]],
#
#         [[ 82,  79,  86],
#          [ 81,  78,  85],
#          [ 81,  78,  85],
#          ...,
#          [ 71,  74,  79],
#          [ 74,  77,  82],
#          [ 74,  77,  82]],
#
#         [[ 81,  78,  85],
#          [ 81,  78,  85],
#          [ 81,  78,  85],
#          ...,
#          [ 71,  74,  79],
#          [ 74,  77,  82],
#          [ 74,  77,  82]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001575.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7544498443603516, 'inference': 4.6138763427734375, 'postprocess': 0.5354881286621094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[176, 186, 190],
#          [176, 186, 190],
#          [176, 186, 190],
#          ...,
#          [191, 199, 203],
#          [192, 200, 204],
#          [192, 200, 204]],
#
#         [[175, 185, 189],
#          [175, 185, 189],
#          [175, 185, 189],
#          ...,
#          [188, 196, 200],
#          [190, 198, 202],
#          [190, 198, 202]],
#
#         [[179, 187, 191],
#          [178, 186, 190],
#          [179, 185, 189],
#          ...,
#          [187, 195, 199],
#          [188, 196, 200],
#          [188, 196, 200]],
#
#         ...,
#
#         [[ 78,  79,  84],
#          [ 78,  79,  84],
#          [ 77,  78,  83],
#          ...,
#          [ 71,  74,  79],
#          [ 73,  76,  81],
#          [ 74,  77,  82]],
#
#         [[ 82,  79,  86],
#          [ 81,  78,  85],
#          [ 81,  78,  85],
#          ...,
#          [ 71,  74,  79],
#          [ 74,  77,  82],
#          [ 74,  77,  82]],
#
#         [[ 81,  78,  85],
#          [ 81,  78,  85],
#          [ 81,  78,  85],
#          ...,
#          [ 71,  74,  79],
#          [ 74,  77,  82],
#          [ 74,  77,  82]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001580.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.8285980224609375, 'inference': 4.841327667236328, 'postprocess': 0.9398460388183594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[185, 191, 195],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [194, 202, 206],
#          [194, 202, 206],
#          [193, 201, 205]],
#
#         [[185, 191, 195],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [194, 202, 206],
#          [194, 202, 206],
#          [193, 201, 205]],
#
#         [[185, 191, 195],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [194, 202, 206],
#          [194, 202, 206],
#          [193, 201, 205]],
#
#         ...,
#
#         [[ 75,  75,  82],
#          [ 75,  75,  82],
#          [ 75,  75,  82],
#          ...,
#          [ 71,  71,  83],
#          [ 71,  71,  83],
#          [ 71,  71,  83]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 73,  73,  85],
#          [ 73,  73,  85],
#          [ 73,  73,  85]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 73,  73,  85],
#          [ 73,  73,  85],
#          [ 73,  73,  85]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001605.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.765655517578125, 'inference': 4.77910041809082, 'postprocess': 0.9386539459228516},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[183, 189, 193],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [197, 201, 210],
#          [196, 200, 209],
#          [195, 199, 208]],
#
#         [[183, 189, 193],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [197, 201, 210],
#          [196, 200, 209],
#          [196, 200, 209]],
#
#         [[183, 189, 193],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [196, 200, 209],
#          [197, 201, 210],
#          [197, 201, 210]],
#
#         ...,
#
#         [[ 75,  75,  82],
#          [ 75,  75,  82],
#          [ 75,  75,  82],
#          ...,
#          [ 71,  71,  83],
#          [ 71,  71,  83],
#          [ 71,  71,  83]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 73,  73,  85],
#          [ 73,  73,  85],
#          [ 73,  73,  85]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 73,  73,  85],
#          [ 73,  73,  85],
#          [ 73,  73,  85]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001610.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7685165405273438, 'inference': 4.626035690307617, 'postprocess': 0.4558563232421875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[183, 189, 193],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [197, 201, 210],
#          [196, 200, 209],
#          [195, 199, 208]],
#
#         [[183, 189, 193],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [197, 201, 210],
#          [196, 200, 209],
#          [196, 200, 209]],
#
#         [[183, 189, 193],
#          [182, 188, 192],
#          [182, 188, 192],
#          ...,
#          [196, 200, 209],
#          [197, 201, 210],
#          [197, 201, 210]],
#
#         ...,
#
#         [[ 75,  75,  82],
#          [ 75,  75,  82],
#          [ 75,  75,  82],
#          ...,
#          [ 71,  72,  82],
#          [ 71,  72,  82],
#          [ 73,  74,  84]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 73,  74,  84],
#          [ 73,  74,  84],
#          [ 73,  74,  84]],
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [ 73,  74,  84],
#          [ 73,  74,  84],
#          [ 73,  74,  84]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001615.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.763509750366211, 'inference': 4.797697067260742, 'postprocess': 0.4706382751464844},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[178, 184, 193],
#          [178, 184, 193],
#          [178, 184, 193],
#          ...,
#          [187, 195, 199],
#          [188, 196, 200],
#          [188, 196, 200]],
#
#         [[178, 184, 193],
#          [178, 184, 193],
#          [178, 184, 193],
#          ...,
#          [187, 195, 199],
#          [187, 195, 199],
#          [187, 195, 199]],
#
#         [[179, 183, 192],
#          [179, 183, 192],
#          [179, 183, 192],
#          ...,
#          [187, 195, 199],
#          [186, 194, 198],
#          [185, 193, 197]],
#
#         ...,
#
#         [[ 73,  78,  84],
#          [ 73,  78,  84],
#          [ 71,  76,  82],
#          ...,
#          [ 71,  67,  77],
#          [ 71,  67,  77],
#          [ 71,  67,  77]],
#
#         [[ 74,  79,  85],
#          [ 74,  79,  85],
#          [ 72,  77,  83],
#          ...,
#          [ 71,  67,  77],
#          [ 71,  67,  77],
#          [ 71,  67,  77]],
#
#         [[ 74,  79,  85],
#          [ 74,  79,  85],
#          [ 72,  77,  83],
#          ...,
#          [ 71,  67,  77],
#          [ 71,  67,  77],
#          [ 71,  67,  77]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001650.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.773284912109375, 'inference': 4.738569259643555, 'postprocess': 0.4742145538330078},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[178, 184, 193],
#          [178, 184, 193],
#          [178, 184, 193],
#          ...,
#          [186, 193, 199],
#          [187, 194, 200],
#          [187, 194, 200]],
#
#         [[178, 184, 193],
#          [178, 184, 193],
#          [178, 184, 193],
#          ...,
#          [186, 193, 199],
#          [187, 194, 200],
#          [187, 194, 200]],
#
#         [[179, 183, 192],
#          [179, 183, 192],
#          [179, 183, 192],
#          ...,
#          [186, 193, 199],
#          [187, 194, 200],
#          [187, 194, 200]],
#
#         ...,
#
#         [[ 73,  78,  84],
#          [ 73,  78,  84],
#          [ 71,  76,  82],
#          ...,
#          [ 66,  67,  77],
#          [ 66,  67,  77],
#          [ 66,  67,  77]],
#
#         [[ 74,  79,  85],
#          [ 74,  79,  85],
#          [ 72,  77,  83],
#          ...,
#          [ 66,  67,  77],
#          [ 66,  67,  77],
#          [ 66,  67,  77]],
#
#         [[ 74,  79,  85],
#          [ 74,  79,  85],
#          [ 72,  77,  83],
#          ...,
#          [ 66,  67,  77],
#          [ 66,  67,  77],
#          [ 66,  67,  77]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001660.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.8035640716552734, 'inference': 4.663705825805664, 'postprocess': 0.4649162292480469},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[177, 187, 191],
#          [176, 186, 190],
#          [175, 185, 189],
#          ...,
#          [187, 192, 198],
#          [187, 192, 198],
#          [186, 191, 197]],
#
#         [[175, 185, 189],
#          [175, 185, 189],
#          [174, 184, 188],
#          ...,
#          [187, 192, 198],
#          [187, 192, 198],
#          [186, 191, 197]],
#
#         [[169, 179, 183],
#          [169, 179, 183],
#          [170, 180, 184],
#          ...,
#          [187, 192, 198],
#          [187, 192, 198],
#          [186, 191, 197]],
#
#         ...,
#
#         [[ 71,  73,  80],
#          [ 71,  73,  80],
#          [ 71,  73,  80],
#          ...,
#          [ 68,  69,  79],
#          [ 68,  69,  79],
#          [ 68,  69,  79]],
#
#         [[ 73,  75,  82],
#          [ 73,  75,  82],
#          [ 73,  75,  82],
#          ...,
#          [ 69,  70,  80],
#          [ 69,  70,  80],
#          [ 69,  70,  80]],
#
#         [[ 73,  75,  82],
#          [ 73,  75,  82],
#          [ 73,  75,  82],
#          ...,
#          [ 69,  70,  80],
#          [ 69,  70,  80],
#          [ 69,  70,  80]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001760.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7265548706054688, 'inference': 4.811763763427734, 'postprocess': 0.47659873962402344},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[180, 184, 193],
#          [182, 186, 195],
#          [182, 186, 195],
#          ...,
#          [197, 199, 206],
#          [197, 199, 206],
#          [196, 198, 205]],
#
#         [[181, 185, 194],
#          [182, 186, 195],
#          [182, 186, 195],
#          ...,
#          [196, 198, 205],
#          [196, 198, 205],
#          [195, 197, 204]],
#
#         [[182, 186, 195],
#          [181, 185, 194],
#          [181, 185, 194],
#          ...,
#          [194, 196, 203],
#          [194, 196, 203],
#          [192, 194, 201]],
#
#         ...,
#
#         [[ 77,  77,  84],
#          [ 77,  77,  84],
#          [ 77,  77,  84],
#          ...,
#          [ 71,  71,  83],
#          [ 71,  71,  83],
#          [ 71,  71,  83]],
#
#         [[ 78,  78,  85],
#          [ 78,  78,  85],
#          [ 78,  78,  85],
#          ...,
#          [ 73,  73,  85],
#          [ 73,  73,  85],
#          [ 73,  73,  85]],
#
#         [[ 78,  78,  85],
#          [ 78,  78,  85],
#          [ 78,  78,  85],
#          ...,
#          [ 73,  73,  85],
#          [ 73,  73,  85],
#          [ 73,  73,  85]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001815.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7480125427246094, 'inference': 4.786252975463867, 'postprocess': 0.7467269897460938},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[188, 198, 202],
#          [188, 198, 202],
#          [188, 198, 202],
#          ...,
#          [210, 216, 220],
#          [211, 217, 221],
#          [213, 219, 223]],
#
#         [[188, 198, 202],
#          [188, 198, 202],
#          [188, 198, 202],
#          ...,
#          [210, 216, 220],
#          [210, 216, 220],
#          [211, 217, 221]],
#
#         [[188, 198, 202],
#          [188, 198, 202],
#          [188, 198, 202],
#          ...,
#          [210, 216, 220],
#          [209, 215, 219],
#          [209, 215, 219]],
#
#         ...,
#
#         [[ 83,  85,  92],
#          [ 83,  85,  92],
#          [ 83,  85,  92],
#          ...,
#          [ 78,  78,  92],
#          [ 78,  78,  92],
#          [ 78,  78,  92]],
#
#         [[ 84,  86,  93],
#          [ 84,  86,  93],
#          [ 84,  86,  93],
#          ...,
#          [ 78,  78,  92],
#          [ 78,  78,  92],
#          [ 78,  78,  92]],
#
#         [[ 84,  86,  93],
#          [ 84,  86,  93],
#          [ 84,  86,  93],
#          ...,
#          [ 78,  78,  92],
#          [ 78,  78,  92],
#          [ 78,  78,  92]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001880.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.8090476989746094, 'inference': 4.578828811645508, 'postprocess': 0.7915496826171875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[201, 209, 213],
#          [198, 206, 210],
#          [195, 203, 207],
#          ...,
#          [206, 214, 218],
#          [206, 214, 218],
#          [206, 214, 218]],
#
#         [[201, 209, 213],
#          [198, 206, 210],
#          [195, 203, 207],
#          ...,
#          [207, 215, 219],
#          [207, 215, 219],
#          [207, 215, 219]],
#
#         [[201, 209, 213],
#          [198, 206, 210],
#          [195, 203, 207],
#          ...,
#          [208, 216, 220],
#          [208, 216, 220],
#          [208, 216, 220]],
#
#         ...,
#
#         [[ 82,  83,  93],
#          [ 82,  83,  93],
#          [ 81,  82,  92],
#          ...,
#          [ 78,  81,  86],
#          [ 78,  81,  86],
#          [ 78,  81,  86]],
#
#         [[ 83,  84,  94],
#          [ 83,  84,  94],
#          [ 82,  83,  93],
#          ...,
#          [ 80,  83,  88],
#          [ 80,  83,  88],
#          [ 80,  83,  88]],
#
#         [[ 83,  84,  94],
#          [ 83,  84,  94],
#          [ 82,  83,  93],
#          ...,
#          [ 80,  83,  88],
#          [ 80,  83,  88],
#          [ 80,  83,  88]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_001940.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.736330032348633, 'inference': 4.608392715454102, 'postprocess': 0.45037269592285156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[181, 195, 200],
#          [191, 205, 210],
#          [196, 215, 219],
#          ...,
#          [220, 234, 239],
#          [220, 234, 239],
#          [224, 238, 243]],
#
#         [[186, 200, 205],
#          [194, 208, 213],
#          [196, 215, 219],
#          ...,
#          [219, 233, 238],
#          [221, 235, 240],
#          [223, 237, 242]],
#
#         [[186, 200, 205],
#          [194, 208, 213],
#          [194, 215, 219],
#          ...,
#          [221, 234, 242],
#          [226, 240, 245],
#          [226, 240, 245]],
#
#         ...,
#
#         [[ 83,  85,  92],
#          [ 83,  85,  92],
#          [ 83,  85,  92],
#          ...,
#          [ 67,  72,  78],
#          [ 67,  72,  78],
#          [ 67,  72,  78]],
#
#         [[ 83,  85,  92],
#          [ 83,  85,  92],
#          [ 83,  85,  92],
#          ...,
#          [ 68,  73,  79],
#          [ 68,  73,  79],
#          [ 68,  73,  79]],
#
#         [[ 83,  85,  92],
#          [ 83,  85,  92],
#          [ 83,  85,  92],
#          ...,
#          [ 68,  73,  79],
#          [ 68,  73,  79],
#          [ 68,  73,  79]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_002300.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7618408203125, 'inference': 4.608392715454102, 'postprocess': 0.453948974609375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[ 66,  65,  75],
#          [ 65,  64,  74],
#          [ 72,  68,  78],
#          ...,
#          [ 90,  94, 103],
#          [ 90,  94, 103],
#          [ 91,  95, 104]],
#
#         [[ 76,  75,  85],
#          [ 76,  75,  85],
#          [ 74,  70,  80],
#          ...,
#          [ 91,  95, 104],
#          [ 94,  98, 107],
#          [ 94,  98, 107]],
#
#         [[ 95,  95, 102],
#          [ 87,  87,  94],
#          [ 75,  75,  82],
#          ...,
#          [ 97, 101, 110],
#          [ 98, 102, 111],
#          [101, 105, 114]],
#
#         ...,
#
#         [[ 83,  85,  92],
#          [ 83,  85,  92],
#          [ 83,  85,  92],
#          ...,
#          [ 66,  71,  77],
#          [ 66,  71,  77],
#          [ 66,  71,  77]],
#
#         [[ 83,  85,  92],
#          [ 83,  85,  92],
#          [ 83,  85,  92],
#          ...,
#          [ 67,  72,  78],
#          [ 67,  72,  78],
#          [ 67,  72,  78]],
#
#         [[ 83,  85,  92],
#          [ 83,  85,  92],
#          [ 83,  85,  92],
#          ...,
#          [ 67,  72,  78],
#          [ 67,  72,  78],
#          [ 67,  72,  78]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_002310.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7823448181152344, 'inference': 4.590511322021484, 'postprocess': 0.4367828369140625},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[214, 223, 224],
#          [220, 229, 230],
#          [218, 226, 230],
#          ...,
#          [ 80,  81,  91],
#          [ 70,  71,  81],
#          [ 66,  67,  77]],
#
#         [[214, 223, 224],
#          [219, 228, 229],
#          [218, 226, 230],
#          ...,
#          [ 83,  84,  94],
#          [ 74,  75,  85],
#          [ 70,  71,  81]],
#
#         [[217, 223, 227],
#          [220, 226, 230],
#          [217, 222, 228],
#          ...,
#          [ 91,  92, 102],
#          [ 82,  83,  93],
#          [ 77,  78,  88]],
#
#         ...,
#
#         [[ 87,  87,  94],
#          [ 87,  87,  94],
#          [ 87,  87,  94],
#          ...,
#          [ 60,  65,  71],
#          [ 60,  65,  71],
#          [ 60,  65,  71]],
#
#         [[ 88,  88,  95],
#          [ 88,  88,  95],
#          [ 88,  88,  95],
#          ...,
#          [ 60,  65,  71],
#          [ 60,  65,  71],
#          [ 60,  65,  71]],
#
#         [[ 88,  88,  95],
#          [ 88,  88,  95],
#          [ 88,  88,  95],
#          ...,
#          [ 60,  65,  71],
#          [ 60,  65,  71],
#          [ 60,  65,  71]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_003260.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.777099609375, 'inference': 4.635334014892578, 'postprocess': 0.4515647888183594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[178, 186, 190],
#          [176, 184, 188],
#          [173, 181, 185],
#          ...,
#          [195, 201, 210],
#          [195, 201, 210],
#          [195, 201, 210]],
#
#         [[179, 187, 191],
#          [177, 185, 189],
#          [174, 182, 186],
#          ...,
#          [195, 201, 210],
#          [195, 201, 210],
#          [195, 201, 210]],
#
#         [[179, 187, 191],
#          [177, 185, 189],
#          [174, 182, 186],
#          ...,
#          [197, 203, 212],
#          [197, 203, 212],
#          [197, 203, 212]],
#
#         ...,
#
#         [[ 69,  70,  80],
#          [ 69,  70,  80],
#          [ 69,  70,  80],
#          ...,
#          [ 70,  73,  78],
#          [ 70,  73,  78],
#          [ 70,  73,  78]],
#
#         [[ 70,  71,  81],
#          [ 70,  71,  81],
#          [ 70,  71,  81],
#          ...,
#          [ 70,  73,  78],
#          [ 70,  73,  78],
#          [ 70,  73,  78]],
#
#         [[ 71,  72,  82],
#          [ 71,  72,  82],
#          [ 71,  72,  82],
#          ...,
#          [ 70,  73,  78],
#          [ 70,  73,  78],
#          [ 70,  73,  78]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_003485.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7680397033691406, 'inference': 4.752159118652344, 'postprocess': 0.5235671997070312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[194, 202, 206],
#          [193, 201, 205],
#          [191, 199, 203],
#          ...,
#          [200, 209, 215],
#          [202, 213, 214],
#          [202, 213, 214]],
#
#         [[194, 202, 206],
#          [193, 201, 205],
#          [191, 199, 203],
#          ...,
#          [200, 209, 215],
#          [202, 213, 214],
#          [202, 213, 214]],
#
#         [[193, 201, 205],
#          [192, 200, 204],
#          [190, 198, 202],
#          ...,
#          [199, 208, 214],
#          [200, 211, 212],
#          [202, 213, 214]],
#
#         ...,
#
#         [[ 76,  77,  82],
#          [ 76,  77,  82],
#          [ 76,  77,  82],
#          ...,
#          [ 72,  73,  78],
#          [ 72,  73,  78],
# ...
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_003960.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.841949462890625, 'inference': 5.0411224365234375, 'postprocess': 0.5056858062744141},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[192, 195, 200],
#          [190, 193, 198],
#          [188, 191, 196],
#          ...,
#          [199, 209, 213],
#          [199, 209, 213],
#          [199, 209, 213]],
#
#         [[194, 197, 202],
#          [191, 194, 199],
#          [190, 193, 198],
#          ...,
#          [200, 210, 214],
#          [200, 210, 214],
#          [200, 210, 214]],
#
#         [[196, 197, 202],
#          [193, 194, 199],
#          [192, 193, 198],
#          ...,
#          [199, 209, 213],
#          [199, 209, 213],
#          [199, 209, 213]],
#
#         ...,
#
#         [[ 77,  77,  84],
#          [ 77,  77,  84],
#          [ 76,  76,  83],
#          ...,
#          [ 76,  72,  82],
#          [ 76,  72,  82],
#          [ 76,  72,  82]],
#
#         [[ 78,  78,  85],
#          [ 78,  78,  85],
#          [ 77,  77,  84],
#          ...,
#          [ 76,  72,  82],
#          [ 76,  72,  82],
#          [ 76,  72,  82]],
#
#         [[ 78,  78,  85],
#          [ 78,  78,  85],
#          [ 77,  77,  84],
#          ...,
#          [ 76,  72,  82],
#          [ 76,  72,  82],
#          [ 76,  72,  82]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004315.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.8581619262695312, 'inference': 5.107879638671875, 'postprocess': 0.5476474761962891},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[102, 101, 111],
#          [102, 101, 111],
#          [104, 103, 113],
#          ...,
#          [ 70,  72,  79],
#          [ 83,  85,  92],
#          [ 89,  91,  98]],
#
#         [[ 97,  96, 106],
#          [ 97,  96, 106],
#          [100,  99, 109],
#          ...,
#          [ 73,  75,  82],
#          [ 89,  91,  98],
#          [ 95,  97, 104]],
#
#         [[ 95,  94, 104],
#          [ 93,  92, 102],
#          [ 95,  94, 104],
#          ...,
#          [ 76,  78,  85],
#          [ 89,  91,  98],
#          [ 96,  98, 105]],
#
#         ...,
#
#         [[ 89,  88, 105],
#          [ 89,  88, 105],
#          [ 89,  88, 105],
#          ...,
#          [ 66,  70,  79],
#          [ 66,  70,  79],
#          [ 66,  70,  79]],
#
#         [[ 89,  88, 105],
#          [ 89,  88, 105],
#          [ 89,  88, 105],
#          ...,
#          [ 66,  70,  79],
#          [ 66,  70,  79],
#          [ 66,  70,  79]],
#
#         [[ 89,  88, 105],
#          [ 89,  88, 105],
#          [ 89,  88, 105],
#          ...,
#          [ 66,  70,  79],
#          [ 66,  70,  79],
#          [ 66,  70,  79]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004740.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 3.279447555541992, 'inference': 6.765604019165039, 'postprocess': 0.6492137908935547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[163, 177, 191],
#          [150, 164, 178],
#          [134, 150, 164],
#          ...,
#          [ 98,  97, 107],
#          [ 97,  96, 106],
#          [ 99,  98, 108]],
#
#         [[182, 196, 210],
#          [170, 184, 198],
#          [155, 171, 185],
#          ...,
#          [ 97,  96, 106],
#          [ 95,  94, 104],
#          [ 97,  96, 106]],
#
#         [[215, 229, 243],
#          [203, 217, 231],
#          [178, 194, 208],
#          ...,
#          [ 94,  93, 103],
#          [ 94,  93, 103],
#          [ 93,  92, 102]],
#
#         ...,
#
#         [[ 93,  89,  99],
#          [ 93,  89,  99],
#          [ 93,  89,  99],
#          ...,
#          [ 66,  64,  83],
#          [ 66,  64,  83],
#          [ 66,  64,  83]],
#
#         [[ 93,  89,  99],
#          [ 93,  89,  99],
#          [ 93,  89,  99],
#          ...,
#          [ 66,  64,  83],
#          [ 66,  64,  83],
#          [ 66,  64,  83]],
#
#         [[ 93,  89,  99],
#          [ 93,  89,  99],
#          [ 93,  89,  99],
#          ...,
#          [ 66,  64,  83],
#          [ 66,  64,  83],
#          [ 66,  64,  83]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004750.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 3.9501190185546875, 'inference': 6.77800178527832, 'postprocess': 0.6425380706787109},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[147, 148, 153],
#          [139, 140, 145],
#          [130, 131, 136],
#          ...,
#          [ 72,  71,  81],
#          [ 68,  67,  77],
#          [ 66,  65,  75]],
#
#         [[173, 174, 179],
#          [160, 161, 166],
#          [151, 152, 157],
#          ...,
#          [ 73,  72,  82],
#          [ 70,  69,  79],
#          [ 68,  67,  77]],
#
#         [[186, 187, 192],
#          [185, 186, 191],
#          [180, 181, 186],
#          ...,
#          [ 76,  75,  85],
#          [ 73,  72,  82],
#          [ 72,  71,  81]],
#
#         ...,
#
#         [[ 93,  89,  99],
#          [ 93,  89,  99],
#          [ 93,  89,  99],
#          ...,
#          [ 66,  64,  83],
#          [ 66,  64,  83],
#          [ 66,  64,  83]],
#
#         [[ 93,  89,  99],
#          [ 93,  89,  99],
#          [ 93,  89,  99],
#          ...,
#          [ 66,  64,  83],
#          [ 66,  64,  83],
#          [ 66,  64,  83]],
#
#         [[ 93,  89,  99],
#          [ 93,  89,  99],
#          [ 93,  89,  99],
#          ...,
#          [ 66,  64,  83],
#          [ 66,  64,  83],
#          [ 66,  64,  83]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004760.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.8352737426757812, 'inference': 5.563259124755859, 'postprocess': 0.7894039154052734},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[174, 181, 187],
#          [172, 179, 185],
#          [174, 181, 187],
#          ...,
#          [105, 107, 114],
#          [ 93,  95, 102],
#          [ 84,  86,  93]],
#
#         [[184, 191, 197],
#          [180, 187, 193],
#          [178, 185, 191],
#          ...,
#          [106, 108, 115],
#          [ 95,  97, 104],
#          [ 85,  87,  94]],
#
#         [[200, 207, 213],
#          [185, 192, 198],
#          [176, 183, 189],
#          ...,
#          [105, 107, 114],
#          [ 92,  94, 101],
#          [ 83,  85,  92]],
#
#         ...,
#
#         [[ 91,  87,  97],
#          [ 91,  87,  97],
#          [ 91,  87,  97],
#          ...,
#          [ 66,  66,  66],
#          [ 66,  65,  67],
#          [ 66,  65,  67]],
#
#         [[ 91,  87,  97],
#          [ 91,  87,  97],
#          [ 91,  87,  97],
#          ...,
#          [ 66,  66,  66],
#          [ 66,  65,  67],
#          [ 66,  65,  67]],
#
#         [[ 91,  87,  97],
#          [ 91,  87,  97],
#          [ 91,  87,  97],
#          ...,
#          [ 66,  66,  66],
#          [ 66,  65,  67],
#          [ 66,  65,  67]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004765.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7763843536376953, 'inference': 4.8007965087890625, 'postprocess': 0.8876323699951172},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[126, 122, 125],
#          [130, 126, 129],
#          [141, 138, 139],
#          ...,
#          [ 71,  73,  80],
#          [ 69,  71,  78],
#          [ 68,  70,  77]],
#
#         [[154, 150, 153],
#          [158, 154, 157],
#          [162, 159, 160],
#          ...,
#          [ 71,  73,  80],
#          [ 69,  71,  78],
#          [ 68,  70,  77]],
#
#         [[182, 179, 178],
#          [187, 184, 183],
#          [185, 182, 181],
#          ...,
#          [ 73,  75,  82],
#          [ 69,  71,  78],
#          [ 70,  72,  79]],
#
#         ...,
#
#         [[ 88,  84,  94],
#          [ 87,  83,  93],
#          [ 86,  82,  92],
#          ...,
#          [ 60,  60,  60],
#          [ 60,  60,  60],
#          [ 60,  60,  60]],
#
#         [[ 88,  84,  94],
#          [ 87,  83,  93],
#          [ 86,  82,  92],
#          ...,
#          [ 60,  60,  60],
#          [ 60,  60,  60],
#          [ 60,  60,  60]],
#
#         [[ 88,  84,  94],
#          [ 87,  83,  93],
#          [ 86,  82,  92],
#          ...,
#          [ 60,  60,  60],
#          [ 60,  60,  60],
#          [ 60,  60,  60]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004770.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7735233306884766, 'inference': 4.760503768920898, 'postprocess': 0.5223751068115234},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[166, 172, 176],
#          [166, 172, 176],
#          [166, 172, 176],
#          ...,
#          [ 55,  61,  65],
#          [ 55,  61,  65],
#          [ 55,  61,  65]],
#
#         [[166, 172, 176],
#          [166, 172, 176],
#          [166, 172, 176],
#          ...,
#          [ 55,  61,  65],
#          [ 55,  61,  65],
#          [ 55,  61,  65]],
#
#         [[163, 169, 173],
#          [163, 169, 173],
#          [163, 169, 173],
#          ...,
#          [ 54,  60,  64],
#          [ 54,  60,  64],
#          [ 54,  60,  64]],
#
#         ...,
#
#         [[ 88,  84,  94],
#          [ 87,  83,  93],
#          [ 86,  82,  92],
#          ...,
#          [ 54,  54,  54],
#          [ 54,  54,  54],
#          [ 54,  54,  54]],
#
#         [[ 88,  84,  94],
#          [ 87,  83,  93],
#          [ 86,  82,  92],
#          ...,
#          [ 54,  54,  54],
#          [ 54,  54,  54],
#          [ 54,  54,  54]],
#
#         [[ 88,  84,  94],
#          [ 87,  83,  93],
#          [ 86,  82,  92],
#          ...,
#          [ 54,  54,  54],
#          [ 54,  54,  54],
#          [ 54,  54,  54]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004775.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.750873565673828, 'inference': 5.069971084594727, 'postprocess': 0.5123615264892578},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[190, 201, 209],
#          [194, 205, 213],
#          [201, 212, 220],
#          ...,
#          [201, 216, 219],
#          [201, 216, 219],
#          [202, 217, 220]],
#
#         [[193, 204, 212],
#          [195, 206, 214],
#          [200, 211, 219],
#          ...,
#          [201, 216, 219],
#          [201, 216, 219],
#          [202, 217, 220]],
#
#         [[199, 207, 216],
#          [199, 207, 216],
#          [197, 208, 216],
#          ...,
#          [203, 216, 219],
#          [203, 216, 219],
#          [204, 217, 220]],
#
#         ...,
#
#         [[ 79,  84,  90],
#          [ 79,  84,  90],
#          [ 79,  84,  90],
#          ...,
#          [ 73,  72,  82],
#          [ 73,  72,  82],
#          [ 73,  72,  82]],
#
#         [[ 81,  86,  92],
#          [ 81,  86,  92],
#          [ 81,  86,  92],
#          ...,
#          [ 73,  72,  82],
#          [ 73,  72,  82],
#          [ 73,  72,  82]],
#
#         [[ 81,  86,  92],
#          [ 81,  86,  92],
#          [ 81,  86,  92],
#          ...,
#          [ 73,  72,  82],
#          [ 73,  72,  82],
#          [ 73,  72,  82]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004955.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7730464935302734, 'inference': 4.700183868408203, 'postprocess': 0.8516311645507812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[205, 210, 221],
#          [205, 210, 221],
#          [205, 210, 221],
#          ...,
#          [216, 218, 225],
#          [216, 218, 225],
#          [216, 218, 225]],
#
#         [[205, 210, 221],
#          [205, 210, 221],
#          [205, 210, 221],
#          ...,
#          [216, 218, 225],
#          [216, 218, 225],
#          [216, 218, 225]],
#
#         [[206, 211, 222],
#          [206, 211, 222],
#          [206, 211, 222],
#          ...,
#          [221, 218, 225],
#          [221, 218, 225],
#          [221, 218, 225]],
#
#         ...,
#
#         [[ 90,  87,  94],
#          [ 90,  87,  94],
#          [ 90,  87,  94],
#          ...,
#          [ 76,  74,  88],
#          [ 76,  74,  88],
#          [ 76,  74,  88]],
#
#         [[ 91,  88,  95],
#          [ 91,  88,  95],
#          [ 91,  88,  95],
#          ...,
#          [ 76,  74,  88],
#          [ 76,  74,  88],
#          [ 76,  74,  88]],
#
#         [[ 91,  88,  95],
#          [ 91,  88,  95],
#          [ 91,  88,  95],
#          ...,
#          [ 76,  74,  88],
#          [ 76,  74,  88],
#          [ 76,  74,  88]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_004975.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.7871131896972656, 'inference': 4.69660758972168, 'postprocess': 0.453948974609375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pole'}
#  obb: None
#  orig_img: array([[[211, 219, 223],
#          [211, 219, 223],
#          [215, 218, 223],
#          ...,
#          [225, 228, 233],
#          [225, 228, 233],
#          [225, 228, 233]],
#
#         [[211, 219, 223],
#          [211, 219, 223],
#          [215, 218, 223],
#          ...,
#          [225, 228, 233],
#          [225, 228, 233],
#          [225, 228, 233]],
#
#         [[211, 219, 223],
#          [211, 219, 223],
#          [215, 218, 223],
#          ...,
#          [225, 228, 233],
#          [225, 228, 233],
#          [225, 228, 233]],
#
#         ...,
#
#         [[ 88,  94,  98],
#          [ 88,  94,  98],
#          [ 88,  94,  98],
#          ...,
#          [ 78,  81,  86],
#          [ 78,  81,  86],
#          [ 78,  81,  86]],
#
#         [[ 89,  95,  99],
#          [ 89,  95,  99],
#          [ 89,  95,  99],
#          ...,
#          [ 78,  81,  86],
#          [ 78,  81,  86],
#          [ 78,  81,  86]],
#
#         [[ 89,  95,  99],
#          [ 89,  95,  99],
#          [ 89,  95,  99],
#          ...,
#          [ 78,  81,  86],
#          [ 78,  81,  86],
#          [ 78,  81,  86]]], dtype=uint8)
#  orig_shape: (1208, 1920)
#  path: '/home/omtalmo/Olaf_TTK4265/Poles/rgb/images/test/frame_005000.PNG'
#  probs: None
#  save_dir: 'SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning'
#  speed: {'preprocess': 2.749204635620117, 'inference': 4.674434661865234, 'postprocess': 0.4627704620361328}]

# %% [markdown]
# ### Run inference on all images and save in output_dir

# %%
import numpy as np
# Create annotators for visualization
bounding_box_annotator = sv.BoundingBoxAnnotator()
# For older versions of supervision, use a simpler approach without custom formatters
label_annotator = sv.LabelAnnotator(
    text_position=sv.Position.TOP_CENTER,
    text_scale=0.5,
    text_thickness=1,
    text_padding=1
)

# Process all test images
print(f"Processing {len(test_images)} test images...")
for image_path in tqdm(test_images):
    # Load and process the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Warning: Could not load {image_path}")
        continue
    
    # Make predictions
    results = model(image)[0]
    
    # Extract confidence values from results
    boxes_data = results.boxes.data.cpu().numpy()
    
    # Create detections with custom class names (using confidence values as labels)
    confidence_labels = [f"{conf:.2f}" for conf in boxes_data[:, 4]]
    
    # Create detections with custom class names
    detections = sv.Detections.from_ultralytics(results)
    detections.class_id = np.zeros_like(detections.class_id)  # Reset class IDs to 0
    
    # Set confidence values as the class names
    class_names = {0: ""}  # Empty string as base class name
    
    # Apply annotations
    annotated_image = bounding_box_annotator.annotate(scene=image, detections=detections)
    annotated_image = label_annotator.annotate(
        scene=annotated_image, 
        detections=detections,
        labels=confidence_labels
    )
    
    # Save the image result
    image_filename = Path(image_path).name
    output_path = os.path.join(output_dir, f"detection_{image_filename}")
    cv2.imwrite(output_path, annotated_image)

print(f"All results saved to {output_dir}")

# Optionally display a montage of some results (first 4 images)
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

for i, image_path in enumerate(test_images[:4]):
    if i >= 4:  # Limit to first 4 images
        break
        
    # Load the saved result
    image_filename = Path(image_path).name
    result_path = os.path.join(output_dir, f"detection_{image_filename}")
    
    if os.path.exists(result_path):
        result_img = cv2.imread(result_path)
        result_img_rgb = cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB)
        axes[i].imshow(result_img_rgb)
        axes[i].set_title(f"{image_filename}")
        axes[i].axis('off')
    
plt.tight_layout()
plt.show()

# Print summary 
print(f"Processed {len(test_images)} images")
print(f"Results saved to: {output_dir}")
# Out:
# Processing 46 test images...
# SupervisionWarnings: BoundingBoxAnnotator is deprecated: `BoundingBoxAnnotator` is deprecated and has been renamed to `BoxAnnotator`. `BoundingBoxAnnotator` will be removed in supervision-0.26.0.
#   0%|          | 0/46 [00:00<?, ?it/s]
# 0: 832x1280 2 poles, 5.0ms
# Speed: 3.6ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.7ms
# Speed: 3.0ms preprocess, 4.7ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.9ms
# Speed: 3.0ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.9ms
# Speed: 3.0ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 4.9ms
# Speed: 3.0ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 4 poles, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 5.0ms
# Speed: 2.9ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 5.0ms
# Speed: 2.9ms preprocess, 5.0ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 5.1ms
# Speed: 3.0ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 5.1ms
# Speed: 3.0ms preprocess, 5.1ms inference, 0.6ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.8ms
# Speed: 2.9ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.6ms
# Speed: 2.9ms preprocess, 4.6ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.6ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.8ms
# Speed: 2.9ms preprocess, 4.8ms inference, 0.6ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.9ms
# Speed: 2.9ms preprocess, 4.9ms inference, 0.7ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 5.2ms
# Speed: 3.0ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 3 poles, 4.9ms
# Speed: 2.9ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.6ms
# Speed: 2.9ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.6ms
# Speed: 2.9ms preprocess, 4.6ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 4.6ms
# Speed: 3.0ms preprocess, 4.6ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 5.5ms
# Speed: 3.0ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.8ms
# Speed: 3.0ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 7.0ms
# Speed: 3.2ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.9ms
# Speed: 2.9ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.6ms
# Speed: 2.9ms preprocess, 4.6ms inference, 0.6ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 4.5ms
# Speed: 2.9ms preprocess, 4.5ms inference, 0.6ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.6ms
# Speed: 2.9ms preprocess, 4.6ms inference, 0.7ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.5ms
# Speed: 2.9ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.6ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.5ms
# Speed: 2.8ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 2 poles, 4.5ms
# Speed: 2.8ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.3ms
# Speed: 2.9ms preprocess, 4.3ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.5ms
# Speed: 2.9ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.4ms
# Speed: 2.8ms preprocess, 4.4ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.5ms
# Speed: 2.9ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.5ms
# Speed: 3.0ms preprocess, 4.5ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.3ms
# Speed: 2.8ms preprocess, 4.3ms inference, 0.5ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.4ms
# Speed: 2.8ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# 0: 832x1280 1 pole, 4.3ms
# Speed: 2.8ms preprocess, 4.3ms inference, 0.4ms postprocess per image at shape (1, 3, 832, 1280)
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 47 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# All results saved to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/results/custom_ar_hyp_tuning_pt_retraining_with_hyp_tuning_imgsz=1280
# Processed 46 images
# Results saved to: /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/results/custom_ar_hyp_tuning_pt_retraining_with_hyp_tuning_imgsz=1280

# %%
import os
import cv2
import numpy as np
from pathlib import Path
from tqdm import tqdm
import numpy as np
import datetime

# Thresholds (clearly defined at the top)
CONFIDENCE_THRESHOLD = 0.5  # Confidence threshold for predictions
IOU_THRESHOLD = 0.5         # IoU threshold for determining true positives

# Define confidence distribution buckets
confidence_distribution = {f"{i/10:.1f}-{(i+1)/10:.1f}": 0 for i in range(10)}

# Evaluation metrics
true_positives = 0
false_positives = 0
false_negatives = 0
total_gt_objects = 0

def calculate_iou(box1, box2):
    """Calculate IoU between two boxes [x1, y1, x2, y2]"""
    # Calculate intersection area
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    
    if x2 < x1 or y2 < y1:
        return 0.0
    
    intersection = (x2 - x1) * (y2 - y1)
    
    # Calculate union area
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union = box1_area + box2_area - intersection
    
    return intersection / union if union > 0 else 0

# Process test images
for img_path in tqdm(valid_images):
    # Extract the base name from the full path correctly
    base_name = Path(img_path).stem  # This gets just the filename without extension
    label_path = os.path.join(valid_label_dir, f"{base_name}.txt")
    
    # Load image
    img = cv2.imread(img_path)
    if img is None:
        print(f"Warning: Could not load {img_path}")
        continue
    
    # Get original image dimensions
    h_orig, w_orig = img.shape[:2]
    
    # Load ground truth labels
    gt_boxes = []
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) >= 5:  # class, x_center, y_center, width, height (normalized)
                    class_id = int(parts[0])
                    x_center = float(parts[1]) * w_orig
                    y_center = float(parts[2]) * h_orig
                    width = float(parts[3]) * w_orig
                    height = float(parts[4]) * h_orig
                    
                    # Convert to [x1, y1, x2, y2] format
                    x1 = x_center - width / 2
                    y1 = y_center - height / 2
                    x2 = x_center + width / 2
                    y2 = y_center + height / 2
                    
                    gt_boxes.append([x1, y1, x2, y2, class_id])
    
    total_gt_objects += len(gt_boxes)
    
    # Run inference with the model
    results = model.predict(img_path, conf=CONFIDENCE_THRESHOLD, verbose=False)
    
    # Extract predictions
    pred_boxes = []
    if len(results) > 0 and hasattr(results[0].boxes, 'data'):
        boxes_data = results[0].boxes.data.cpu().numpy()
        for box in boxes_data:
            x1, y1, x2, y2, conf, cls_id = box
            
            # Record confidence distribution
            conf_val = float(conf)
            conf_bucket = min(int(conf_val * 10), 9)
            conf_range = f"{conf_bucket/10:.1f}-{(conf_bucket+1)/10:.1f}"
            confidence_distribution[conf_range] += 1
            
            pred_boxes.append([float(x1), float(y1), float(x2), float(y2), float(conf), int(cls_id)])
    
    # Evaluate predictions against ground truth
    matched_gt = [False] * len(gt_boxes)
    
    for pred_box in pred_boxes:
        x1, y1, x2, y2, conf, cls_id = pred_box
        pred_bbox = [x1, y1, x2, y2]
        
        best_iou = 0
        best_gt_idx = -1
        
        # Find the best matching ground truth box
        for i, gt_box in enumerate(gt_boxes):
            if matched_gt[i]:
                continue  # Skip already matched ground truth boxes
                
            gt_bbox = gt_box[:4]
            iou = calculate_iou(pred_bbox, gt_bbox)
            
            if iou > best_iou:
                best_iou = iou
                best_gt_idx = i
        
        # Check if prediction is a true positive or false positive
        if best_iou >= IOU_THRESHOLD:
            true_positives += 1
            if best_gt_idx >= 0:
                matched_gt[best_gt_idx] = True
        else:
            false_positives += 1
    
    # Count false negatives (unmatched ground truth boxes)
    false_negatives += matched_gt.count(False)

# Calculate metrics
precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# Calculate additional metrics
miss_rate = false_negatives / total_gt_objects if total_gt_objects > 0 else float('nan')
fdr = false_positives / (false_positives + true_positives) if (false_positives + true_positives) > 0 else float('nan')
total_accuracy = true_positives / (total_gt_objects + false_positives) if (total_gt_objects + false_positives) > 0 else float('nan')

# Print results
print("\nEvaluation Results:")
print(f"Total test images: {len(valid_images)}")
print(f"Total ground truth objects: {total_gt_objects}")
print(f"Confidence threshold: {CONFIDENCE_THRESHOLD}, IoU threshold: {IOU_THRESHOLD}")
print(f"True positives: {true_positives}")
print(f"False positives: {false_positives}")
print(f"False negatives: {false_negatives}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"Miss rate: {miss_rate:.4f}")
print(f"False discovery rate: {fdr:.4f}")
print(f"Total accuracy: {total_accuracy:.4f}")

# Print confidence distribution
print("\nConfidence Distribution:")
for conf_range, count in sorted(confidence_distribution.items()):
    print(f"  {conf_range}: {count} predictions")

# Save results to text file with timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
eval_results_path = os.path.join(output_dir, f"model_evaluation_results_{timestamp}.txt")

with open(eval_results_path, 'w') as f:
    f.write("===== YOLOv12 Model Evaluation Results =====\n")
    f.write(f"Date: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"Model: {str(model.ckpt_path)}\n\n")
    
    f.write("===== Basic Metrics =====\n")
    f.write(f"Total ground truth boxes: {total_gt_objects}\n")
    f.write(f"Total predictions: {true_positives + false_positives}\n")
    f.write(f"True positives: {true_positives}\n")
    f.write(f"False positives: {false_positives}\n")
    f.write(f"False negatives: {false_negatives}\n")
    f.write(f"Precision: {precision:.4f}\n")
    f.write(f"Recall: {recall:.4f}\n")
    f.write(f"F1 Score: {f1_score:.4f}\n\n")
    
    f.write("===== Additional Metrics =====\n")
    if not np.isnan(miss_rate):
        f.write(f"Miss rate: {miss_rate:.4f}\n")
    else:
        f.write("Miss rate: N/A\n")
        
    if not np.isnan(fdr):
        f.write(f"False discovery rate: {fdr:.4f}\n")
    else:
        f.write("False discovery rate: N/A\n")
        
    if not np.isnan(total_accuracy):
        f.write(f"Total accuracy: {total_accuracy:.4f}\n")
    else:
        f.write("Total accuracy: N/A\n")

print(f"\nEvaluation results saved to: {eval_results_path}")
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 48 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 49 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#   2%|▏         | 2/92 [00:00<00:04, 18.49it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 50 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 51 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#   4%|▍         | 4/92 [00:00<00:04, 19.10it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 52 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 53 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#   7%|▋         | 6/92 [00:00<00:04, 19.48it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 54 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 55 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 56 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  10%|▉         | 9/92 [00:00<00:04, 19.85it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 57 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 58 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  12%|█▏        | 11/92 [00:00<00:04, 19.74it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 59 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 60 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 61 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  15%|█▌        | 14/92 [00:00<00:03, 20.03it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 61 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 61 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 62 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  18%|█▊        | 17/92 [00:00<00:03, 20.01it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 63 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 64 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  21%|██        | 19/92 [00:00<00:03, 19.76it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 65 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 66 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  23%|██▎       | 21/92 [00:01<00:03, 19.69it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 67 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 68 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 69 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  26%|██▌       | 24/92 [00:01<00:03, 19.94it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 70 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 71 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  28%|██▊       | 26/92 [00:01<00:03, 19.87it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 72 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 73 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  30%|███       | 28/92 [00:01<00:03, 19.84it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 74 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 75 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  33%|███▎      | 30/92 [00:01<00:03, 19.88it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 76 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 77 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  35%|███▍      | 32/92 [00:01<00:03, 19.30it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 78 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 79 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  37%|███▋      | 34/92 [00:01<00:02, 19.34it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 80 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 81 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  39%|███▉      | 36/92 [00:01<00:02, 19.38it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 82 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 83 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 84 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  42%|████▏     | 39/92 [00:01<00:02, 19.34it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 85 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 86 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 87 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  46%|████▌     | 42/92 [00:02<00:02, 19.77it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 88 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 89 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  48%|████▊     | 44/92 [00:02<00:02, 19.48it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 90 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 91 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  50%|█████     | 46/92 [00:02<00:02, 19.26it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 92 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 93 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  52%|█████▏    | 48/92 [00:02<00:02, 19.22it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 94 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 95 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 96 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  55%|█████▌    | 51/92 [00:02<00:02, 19.40it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 97 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 98 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  58%|█████▊    | 53/92 [00:02<00:02, 19.39it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 99 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 100 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  60%|█████▉    | 55/92 [00:02<00:01, 19.43it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 101 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 102 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  62%|██████▏   | 57/92 [00:02<00:01, 19.45it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 102 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 102 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 103 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  65%|██████▌   | 60/92 [00:03<00:01, 19.33it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 104 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 105 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 106 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  68%|██████▊   | 63/92 [00:03<00:01, 19.60it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 107 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 108 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  71%|███████   | 65/92 [00:03<00:01, 19.47it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 108 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 109 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 110 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  74%|███████▍  | 68/92 [00:03<00:01, 19.88it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 111 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 112 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  76%|███████▌  | 70/92 [00:03<00:01, 19.59it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 113 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 114 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  78%|███████▊  | 72/92 [00:03<00:01, 19.55it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 115 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 116 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  80%|████████  | 74/92 [00:03<00:00, 19.33it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 117 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 118 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  83%|████████▎ | 76/92 [00:03<00:00, 19.06it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 119 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 120 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  85%|████████▍ | 78/92 [00:03<00:00, 19.22it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 121 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 122 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  87%|████████▋ | 80/92 [00:04<00:00, 18.79it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 123 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 124 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 125 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  90%|█████████ | 83/92 [00:04<00:00, 19.14it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 126 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 127 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  92%|█████████▏| 85/92 [00:04<00:00, 19.15it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 128 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 129 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  95%|█████████▍| 87/92 [00:04<00:00, 19.25it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 130 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 131 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 132 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#  98%|█████████▊| 90/92 [00:04<00:00, 19.71it/s]
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 133 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 134 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# 100%|██████████| 92/92 [00:04<00:00, 19.52it/s]
# Evaluation Results:
# Total test images: 92
# Total ground truth objects: 113
# Confidence threshold: 0.5, IoU threshold: 0.5
# True positives: 100
# False positives: 2
# False negatives: 13
# Precision: 0.9804
# Recall: 0.8850
# F1 Score: 0.9302
# Miss rate: 0.1150
# False discovery rate: 0.0196
# Total accuracy: 0.8696
#
# Confidence Distribution:
#   0.0-0.1: 0 predictions
#   0.1-0.2: 0 predictions
#   0.2-0.3: 0 predictions
#   0.3-0.4: 0 predictions
#   0.4-0.5: 0 predictions
#   0.5-0.6: 6 predictions
#   0.6-0.7: 5 predictions
#   0.7-0.8: 23 predictions
#   0.8-0.9: 67 predictions
#   0.9-1.0: 1 predictions
#
# Evaluation results saved to: /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/results/custom_ar_hyp_tuning_pt_retraining_with_hyp_tuning_imgsz=1280/model_evaluation_results_20250430_163227.txt

# %% [markdown]
# ### Visualize all rejected bounding boxes

# %%
import os
import cv2
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics.utils.tal import make_anchors

def visualize_feature_maps_and_boxes(image_path, model, conf_threshold=0.00001):
    """
    Visualize YOLOv12's detection process at a lower level:
    1. Original image
    2. All potential boxes based on anchor points
    3. Feature activation maps
    
    Args:
        image_path: Path to the image
        model: YOLO model
        conf_threshold: Extremely low threshold to see all possible candidates
    """
    # Load image
    image = cv2.imread(image_path)
    original_image = image.copy()
    h, w = image.shape[:2]
    
    # Create figure with 2x2 grid
    fig, axes = plt.subplots(2, 2, figsize=(20, 16))
    fig.suptitle(f"YOLOv12 Deep Visualization", fontsize=16)
    
    # 1. Original image (top-left)
    axes[0, 0].imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    axes[0, 0].set_title("Original Image")
    axes[0, 0].axis('off')
    
    # 2. Anchor points with primitive boxes (top-right)
    # Get the feature maps and stride info from the model
    stride = model.model.stride
    features = [torch.zeros(1, 3, h // int(s), w // int(s)) for s in stride]
    
    # Generate anchors similar to how YOLOv12 does internally
    anchor_points, stride_tensor = make_anchors(features, stride)
    anchor_points = anchor_points.cpu().numpy()
    
    # Plot anchor points on original image with potential boxes
    anchor_img = original_image.copy()
    axes[0, 1].imshow(cv2.cvtColor(anchor_img, cv2.COLOR_BGR2RGB))
    
    # Draw grid for each stride with different colors and sample boxes
    colors = ['red', 'green', 'blue', 'yellow', 'cyan']
    legend_elements = []
    
    # Draw sample potential boxes at each anchor point
    # These are theoretical boxes before any prediction happens
    for i, s in enumerate(stride):
        s = int(s)
        color = colors[i % len(colors)]
        
        # Create grid points for this stride
        x_points = np.arange(s//2, w, s)
        y_points = np.arange(s//2, h, s)
        
        # Sample some points to avoid overcrowding (10% of points)
        np.random.seed(42)  # For reproducibility
        sample_size = max(1, int(0.1 * len(x_points) * len(y_points)))
        x_samples = np.random.choice(x_points, min(10, len(x_points)), replace=False)
        y_samples = np.random.choice(y_points, min(10, len(y_points)), replace=False)
        
        # Draw anchor points
        for x in x_points:
            for y in y_points:
                axes[0, 1].add_patch(plt.Circle((x, y), radius=1, color=color, alpha=0.5))
                
        # Draw sample bounding boxes at selected anchor points
        # Using multiple aspect ratios to show potential boxes (thin, medium, wide)
        aspect_ratios = [0.2, 1.0, 5.0]  # width/height ratios
        
        for x in x_samples:
            for y in y_samples:
                for ratio in aspect_ratios:
                    # Size proportional to stride
                    width = s * np.sqrt(ratio) * 1.5
                    height = s / np.sqrt(ratio) * 1.5
                    
                    rect = plt.Rectangle(
                        (x - width/2, y - height/2),
                        width, height,
                        linewidth=0.5,
                        edgecolor=color,
                        facecolor='none',
                        alpha=0.4
                    )
                    axes[0, 1].add_patch(rect)
        
        legend_elements.append(plt.Line2D([0], [0], marker='o', color=color, 
                                        label=f'Stride {s}', markersize=8, linestyle='None'))
    
    axes[0, 1].legend(handles=legend_elements, loc='upper right')
    axes[0, 1].set_title(f"Anchor Points Grid ({len(anchor_points)} points) with Potential Boxes")
    axes[0, 1].axis('off')
    
    # 3. Lowest confidence predictions (bottom-left)
    # Run prediction with extremely low confidence to capture more boxes
    results_low_conf = model.predict(image_path, conf=conf_threshold, verbose=False, nms=False)
    boxes_low_conf = results_low_conf[0].boxes.data.cpu().numpy()
    
    # Draw all detected boxes from explicit prediction
    low_conf_img = original_image.copy()
    
    # Count boxes by confidence ranges
    conf_ranges = {
        'very_low': [conf_threshold, 0.01],
        'low': [0.01, 0.1],
        'medium': [0.1, 0.5], 
        'high': [0.5, 1.0]
    }
    
    box_counts = {range_name: 0 for range_name in conf_ranges}
    
    for box in boxes_low_conf:
        x1, y1, x2, y2 = map(int, box[:4])
        conf = float(box[4])
        
        # Determine confidence range
        for range_name, (min_conf, max_conf) in conf_ranges.items():
            if min_conf <= conf < max_conf:
                box_counts[range_name] += 1
                break
                
        # Color based on confidence (green to red)
        color_b = max(0, int(255 * (1-conf)))  
        color_g = max(0, int(255 * conf))
        color_r = max(0, int(255 * (0.5 - abs(conf - 0.5)) * 2))  # Peak at 0.5 conf
        
        cv2.rectangle(low_conf_img, (x1, y1), (x2, y2), (color_b, color_g, color_r), 1)
    
    axes[1, 0].imshow(cv2.cvtColor(low_conf_img, cv2.COLOR_BGR2RGB))
    
    # Create legend text for confidence ranges
    conf_text = "\n".join([
        f"{range_name.replace('_', ' ').title()}: {count} boxes ({min_conf:.4f}-{max_conf:.1f})"
        for range_name, count in box_counts.items()
        for min_conf, max_conf in [conf_ranges[range_name]]
    ])
    
    total_boxes = sum(box_counts.values())
    axes[1, 0].text(10, 30, f"Total: {total_boxes} boxes\n{conf_text}", 
                    bbox=dict(facecolor='white', alpha=0.7), fontsize=9)
    
    axes[1, 0].set_title(f"All Raw Predictions: {len(boxes_low_conf)} boxes")
    axes[1, 0].axis('off')
    
    # 4. Final filtered predictions (bottom-right)
    results = model.predict(image_path, conf=0.25, verbose=False)  # Standard filtering
    detections = sv.Detections.from_ultralytics(results[0])
    
    # Draw final boxes
    final_img = original_image.copy()
    final_img = bounding_box_annotator.annotate(scene=final_img, detections=detections)
    final_img = label_annotator.annotate(scene=final_img, detections=detections)
    
    axes[1, 1].imshow(cv2.cvtColor(final_img, cv2.COLOR_BGR2RGB))
    axes[1, 1].set_title(f"Final Detections After Filtering: {len(detections)}")
    axes[1, 1].axis('off')
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    
    # Save the visualization
    image_filename = Path(image_path).name
    fig_path = os.path.join(output_dir, f"deep_vis_{image_filename.split('.')[0]}.png")
    fig.savefig(fig_path, bbox_inches='tight')
    
    print(f"Total potential boxes: {len(anchor_points)}")
    print(f"Actual detected boxes (very low conf): {total_boxes}")
    print(f"Final detections: {len(detections)}")
    
    return fig, total_boxes

# Run visualization with extremely low confidence to see more boxes
example_image_path = test_images[0]
fig, box_count = visualize_feature_maps_and_boxes(example_image_path, model, conf_threshold=0.00001)
plt.show()

print(f"Found {box_count} candidate boxes total")
print(f"Visualization saved to {output_dir}")

# Try with one more image
if len(test_images) > 1:
    fig, count = visualize_feature_maps_and_boxes(test_images[1], model, conf_threshold=0.00001)
    print(f"Image 2: Found {count} candidate boxes")
    plt.close(fig)
# Out:
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 134 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 134 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Total potential boxes: 47460
# Actual detected boxes (very low conf): 30
# Final detections: 2
# Found 30 candidate boxes total
# Visualization saved to /home/omtalmo/Olaf_TTK4265/TDT4265-Snow-pole-detection/yolov12_our_files/results/custom_ar_hyp_tuning_pt_retraining_with_hyp_tuning_imgsz=1280
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 134 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 134 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
# Total potential boxes: 47460
# Actual detected boxes (very low conf): 16
# Final detections: 1
# Image 2: Found 16 candidate boxes

# %% [markdown]
# ### Aspect ration analysis for 1 image

# %%
import os
import cv2
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path
from collections import defaultdict

def analyze_box_aspect_ratios(image_path, model, conf_threshold=0.00001):
    """
    Analyze and visualize aspect ratios of the detected bounding boxes.
    
    Args:
        image_path: Path to the image
        model: YOLO model
        conf_threshold: Threshold for box detection
    """
    # Load image
    image = cv2.imread(image_path)
    original_image = image.copy()
    h, w = image.shape[:2]
    
    # Run prediction with extremely low confidence to capture all boxes
    print("Getting predictions with very low confidence threshold...")
    results_low_conf = model.predict(image_path, conf=conf_threshold, verbose=False, nms=False)
    boxes_low_conf = results_low_conf[0].boxes.data.cpu().numpy()
    
    # Calculate aspect ratios for all boxes
    aspect_ratios = []
    for box in boxes_low_conf:
        x1, y1, x2, y2 = map(int, box[:4])
        width = x2 - x1
        height = y2 - y1
        # Avoid division by zero
        if height == 0:
            continue
        aspect_ratio = width / height
        aspect_ratios.append(aspect_ratio)
    
    # Define aspect ratio categories
    categories = {
        'very_tall': (0, 0.33),     # height is 3x+ width
        'tall': (0.33, 0.67),       # height is 1.5x to 3x width
        'slightly_tall': (0.67, 0.9), # height slightly larger than width
        'square': (0.9, 1.1),       # roughly square
        'slightly_wide': (1.1, 1.5), # width slightly larger than height
        'wide': (1.5, 3.0),        # width is 1.5x to 3x height
        'very_wide': (3.0, float('inf')) # width is 3x+ height
    }
    
    # Categorize boxes
    categorized = defaultdict(list)
    for ar in aspect_ratios:
        for category, (min_ar, max_ar) in categories.items():
            if min_ar <= ar < max_ar:
                categorized[category].append(ar)
                break
    
    # Count categories
    category_counts = {category: len(boxes) for category, boxes in categorized.items()}
    total_boxes = len(aspect_ratios)
    
    # Create figure for visualization
    fig, axes = plt.subplots(1, 2, figsize=(20, 8))
    fig.suptitle(f"Bounding Box Aspect Ratio Analysis: {Path(image_path).name}", fontsize=16)
    
    # 1. Original image with all bounding boxes colored by aspect ratio
    # Create a copy of the original image
    aspect_ratio_image = original_image.copy()
    
    # Color mapping for categories
    color_map = {
        'very_tall': (0, 0, 255),     # Red
        'tall': (0, 127, 255),         # Orange
        'slightly_tall': (0, 255, 255), # Yellow
        'square': (0, 255, 0),         # Green
        'slightly_wide': (255, 255, 0), # Cyan
        'wide': (255, 0, 0),           # Blue
        'very_wide': (255, 0, 255)      # Magenta
    }
    
    # Draw boxes with category-based coloring
    for box in boxes_low_conf:
        x1, y1, x2, y2 = map(int, box[:4])
        width = x2 - x1
        height = y2 - y1
        
        # Avoid division by zero
        if height == 0:
            continue
            
        aspect_ratio = width / height
        
        # Determine category
        box_category = None
        for category, (min_ar, max_ar) in categories.items():
            if min_ar <= aspect_ratio < max_ar:
                box_category = category
                break
                
        # Get color based on category
        color = color_map.get(box_category, (255, 255, 255))
        
        # Draw rectangle
        cv2.rectangle(aspect_ratio_image, (x1, y1), (x2, y2), color, 2)
    
    # Display image
    axes[0].imshow(cv2.cvtColor(aspect_ratio_image, cv2.COLOR_BGR2RGB))
    axes[0].set_title(f"Boxes by Aspect Ratio Category (total: {total_boxes})")
    axes[0].axis('off')
    
    # Create legend for categories
    legend_elements = []
    for category, color in color_map.items():
        # Convert BGR to RGB for matplotlib
        color_rgb = (color[2]/255, color[1]/255, color[0]/255)
        count = len(categorized[category])
        percentage = (count / total_boxes * 100) if total_boxes > 0 else 0
        
        # Create patch for legend
        patch = plt.Rectangle((0, 0), 1, 1, facecolor=color_rgb, edgecolor='black')
        legend_elements.append((patch, f"{category}: {count} boxes ({percentage:.1f}%)"))
    
    # Add legend to first subplot
    legend_patches = [item[0] for item in legend_elements]
    legend_labels = [item[1] for item in legend_elements]
    axes[0].legend(legend_patches, legend_labels, loc='upper right')
    
    # 2. Histogram of aspect ratios
    axes[1].hist(aspect_ratios, bins=50, range=(0, 5), alpha=0.7, color='blue')
    axes[1].set_title(f"Distribution of Aspect Ratios (width/height)")
    axes[1].set_xlabel("Aspect Ratio (width/height)")
    axes[1].set_ylabel("Number of Boxes")
    axes[1].grid(alpha=0.3)
    
    # Add vertical lines for category boundaries
    colors = ['r', 'orange', 'y', 'g', 'c', 'b', 'm']
    for i, (category, (min_val, max_val)) in enumerate(categories.items()):
        if min_val > 0:
            axes[1].axvline(x=min_val, color=colors[i % len(colors)], linestyle='--', alpha=0.5)
    
    # Add vertical line at aspect ratio = 1 (square)
    axes[1].axvline(x=1.0, color='g', linestyle='-', alpha=0.8, label="Square (AR=1)")
    
    # Add text showing statistics
    stats_text = "\n".join([
        f"Total boxes: {total_boxes}",
        f"Mean aspect ratio: {np.mean(aspect_ratios):.2f}",
        f"Median aspect ratio: {np.median(aspect_ratios):.2f}",
        f"Min aspect ratio: {min(aspect_ratios):.2f}",
        f"Max aspect ratio: {max(aspect_ratios):.2f}"
    ])
    axes[1].text(0.95, 0.95, stats_text, 
                transform=axes[1].transAxes, 
                fontsize=10, 
                bbox=dict(facecolor='white', alpha=0.7),
                verticalalignment='top', 
                horizontalalignment='right')
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    
    # Save the visualization
    image_filename = Path(image_path).name
    fig_path = os.path.join(output_dir, f"aspect_ratio_analysis_{image_filename.split('.')[0]}.png")
    fig.savefig(fig_path, bbox_inches='tight')
    
    # Print summary statistics
    print("\n=== Bounding Box Aspect Ratio Analysis ===")
    print(f"Total boxes analyzed: {total_boxes}")
    print("\nCategory distribution:")
    for category, count in category_counts.items():
        percentage = (count / total_boxes * 100) if total_boxes > 0 else 0
        min_val, max_val = categories[category]
        print(f"  {category}: {count} boxes ({percentage:.1f}%) - AR range: {min_val:.2f} to {max_val:.2f}")
    
    print("\nStatistical summary:")
    print(f"  Mean aspect ratio: {np.mean(aspect_ratios):.2f}")
    print(f"  Median aspect ratio: {np.median(aspect_ratios):.2f}")
    print(f"  Standard deviation: {np.std(aspect_ratios):.2f}")
    print(f"  Min aspect ratio: {min(aspect_ratios):.2f}")
    print(f"  Max aspect ratio: {max(aspect_ratios):.2f}")
    
    return aspect_ratios, categorized, fig

# Run the aspect ratio analysis
example_image_path = test_images[0]
aspect_ratios, categorized_boxes, fig = analyze_box_aspect_ratios(example_image_path, model, conf_threshold=0.00001)
plt.show()

# Try with one more image if available
if len(test_images) > 1:
    aspect_ratios2, categorized_boxes2, fig2 = analyze_box_aspect_ratios(test_images[1], model, conf_threshold=0.00001)
    plt.show()
# Out:
# Getting predictions with very low confidence threshold...
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 134 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# === Bounding Box Aspect Ratio Analysis ===
# Total boxes analyzed: 30
#
# Category distribution:
#   very_tall: 28 boxes (93.3%) - AR range: 0.00 to 0.33
#   tall: 1 boxes (3.3%) - AR range: 0.33 to 0.67
#   square: 1 boxes (3.3%) - AR range: 0.90 to 1.10
#
# Statistical summary:
#   Mean aspect ratio: 0.15
#   Median aspect ratio: 0.10
#   Standard deviation: 0.19
#   Min aspect ratio: 0.03
#   Max aspect ratio: 1.09
# Getting predictions with very low confidence threshold...
# Results saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning
# 134 labels saved to SAVE_FOLDER/retraining_on_custom_ar_hyp_tuning_pt_with_imgsz=1280_and_hyp_tuning/labels
#
# === Bounding Box Aspect Ratio Analysis ===
# Total boxes analyzed: 16
#
# Category distribution:
#   very_tall: 15 boxes (93.8%) - AR range: 0.00 to 0.33
#   tall: 1 boxes (6.2%) - AR range: 0.33 to 0.67
#
# Statistical summary:
#   Mean aspect ratio: 0.10
#   Median aspect ratio: 0.06
#   Standard deviation: 0.12
#   Min aspect ratio: 0.03
#   Max aspect ratio: 0.54
